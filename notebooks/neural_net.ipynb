# %% [markdown]
# # Neural Network Model of NBA All-Star Predictions:

# %% [markdown]
# ## Libraries/Requirements:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    roc_auc_score, precision_score, recall_score,
    f1_score, accuracy_score
)
import os
from pathlib import Path
import torch
import torch.nn as nn

# %% [markdown]
# ## Deterministic Setup and Hyperparameter Selection:

# %%
class Config:
    """
        Central configuration for the neural network model.
        Defines training hyperparameters, model architecture, loss weighting,
        data split boundaries, and runtime device. The goal is to keep all
        experimental knobs in one place for reproducibility and clarity.
        Notes:
        - HIDDEN_DIMS controls the MLP depth/width before attention.
        - ATTN controls interaction modeling across players in a group.
        - TOPK_TEMP controls sharpness of soft selection.
        - Loss weights balance ranking vs calibration vs structured selection.
        - TRAIN_END / VAL_END enforce temporal splits to avoid leakage.
    """
    SEED = 47
    LR = 0.00005
    WD_VALUES = np.logspace(-6, -2, 10)
    EPOCHS = 80
    HIDDEN_DIMS = [256, 128, 64]
    DROPOUT = 0.1
    ATTN_HEADS = 4
    ATTN_DIM = ATTN_HEADS * 32
    TOPK_TEMP = 0.34
    PAIRWISE_WEIGHT = 0.3
    BCE_WEIGHT = 0.4
    GRAD_CLIP = 1.0
    TRAIN_END = 2015
    VAL_END = 2021
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    DATA_PATH = 'source\\cleaned\\cleaned_data.csv'

def set_seed(seed):
    """
        Fixes all major sources of randomness for reproducibility.
        Ensures consistent results across:
        - PyTorch (CPU + CUDA)
        - NumPy
        - cuDNN backend
        This makes training deterministic at the cost of some performance.
    """
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def build_group_indices(df, device):
    """
        Groups indices by (season, conference).
        Returns a list of index tensors, where each tensor corresponds to a
        single selection pool (i.e., one conference in one season).
        This is critical because:
        - Attention is applied within groups
        - Loss functions (top-k, pairwise) operate at the group level
        - Selection constraints are enforced per group
        Output:
            List[Tensor]: each tensor contains indices for one group
    """
    keys = df[['Season Ending Year', 'Conference_East']].values

    groups = {}
    for i, k in enumerate(map(tuple, keys)):
        groups.setdefault(k, []).append(i)

    return [
        torch.tensor(v, dtype=torch.long, device=device)
        for v in groups.values()
    ]

def get_project_root():
    """
        Dynamically locates the project root directory.
        Walks up the directory tree until a folder containing 'source/'
        is found. This avoids hardcoding file paths and makes the project
        portable across environments (local, notebook, different machines).
        Raises:
            FileNotFoundError if the expected structure is not found.
    """
    current = Path.cwd()
    for parent in [current] + list(current.parents):
        if (parent / "source").exists():  
            return parent
    raise FileNotFoundError("Could not find project root (missing 'source' folder)")

ROOT = get_project_root()
DATA_PATH = ROOT / "source" / "cleaned" / "cleaned_data.csv"

# %% [markdown]
# The Configuration class defined above enables modular setups and experiments, and reproducible and consistent results across different runs. This then allows for future work and for exploration of the importance of parameter values, which are defined as follows:
#
# | Component        | Parameter        | Value            | Meaning |
# |------------------|------------------|------------------|--------|
# | Reproducibility  | Seed             | 47               | Fixes randomness across NumPy and PyTorch |
# | Training         | Learning Rate    | 5e-5             | Keeps updates small to stabilize training |
# | Training         | Weight Decay     | 1e-5             | L2 regularization to control overfitting |
# | Training         | Epochs           | 80               | Enough to converge without drifting |
# | Architecture     | Hidden Dims      | [256, 128, 64]   | Expands then compresses representation |
# | Architecture     | Dropout          | 0.1              | Light regularization without underfitting |
# | Attention        | Heads            | 4                | Captures multiple interaction patterns |
# | Attention        | Dimension        | 128              | Total embedding size across heads |
# | Objective        | Temperature      | 0.34             | Sharpens soft top-k selection |
# | Objective        | Pairwise Weight  | 0.3              | Pushes true All-Stars above others |
# | Objective        | BCE Weight       | 0.4              | Keeps probabilities calibrated |
# | Optimization     | Grad Clip        | 1.0              | Prevents unstable gradients |
# | Data Split       | Train End        | 2015             | Trains only on past seasons |
# | Data Split       | Val End          | 2021             | Holds out recent seasons for tuning |
# | Hardware         | Device           | GPU / CPU        | Uses GPU if available |
# | Structure        | Grouping         | (Season, Conf)   | Defines each selection pool |
# | Data             | Path             | relative to root | Makes the pipeline portable |

# %% [markdown]
# ## Data Pipeline:

# %%
class DataPipeline:
    """
        End-to-end data processing pipeline.
        Handles:
        - feature construction (domain + contextual features)
        - temporal splitting (train / val / test)
        - normalization and tensor conversion
        The design emphasizes relative performance within a season/conference
        and preserves group structure for downstream attention and selection.
    """
    def __init__(self, cfg):
        """
            Initializes preprocessing components.
            Uses standard scaling to normalize feature magnitudes,
            which stabilizes optimization for the neural network.
        """
        self.cfg = cfg
        self.scaler = StandardScaler()

    def load(self, path):
        """
            Loads raw CSV data and applies feature engineering.
            Args:
                path (str or Path): location of cleaned dataset
            Returns:
                DataFrame with engineered features
        """
        df = pd.read_csv(path)
        return self._features(df)

    def _features(self, df):
        """
            Constructs domain-informed and contextual features.
            Key ideas:
            - Encode categorical structure (conference, position, season)
            - Capture usage and scoring impact
            - Normalize performance within (season, conference)
            - Add temporal signals (previous All-Star selections)
            Feature groups:
            - IDs: Conf_ID, Pos_ID, Season_ID (for embeddings)
            - Usage/impact: Usage, Usage_x_Win, Impact_on_winning
            - Relative scoring: PTS_conf_z, PTS_conf_share
            - Relative impact: Impact_conf_z
            - Temporal: AllStar_Last_Year, AllStar_last_2
            Returns:
                DataFrame with additional feature columns
        """

        df['Conf_ID'] = df['Conference_East'].astype(int)
        df['Pos_ID'] = df['PosGroup_Backcourt'].astype(int)

        min_year = df['Season Ending Year'].min()
        df['Season_ID'] = df['Season Ending Year'] - min_year

        df['Usage'] = df['FGA per game'] + 0.44 * df['FTA per game']
        df['Usage_x_Win'] = df['Usage'] * df['Team Win %']
        df['Impact_on_winning'] = df['PTS per game'] * df['Team Win %']

        group_keys = ['Season Ending Year', 'Conference_East']

        pts_mean = df.groupby(group_keys)['PTS per game'].transform('mean')
        pts_std = df.groupby(group_keys)['PTS per game'].transform('std')

        df['PTS_conf_z'] = (df['PTS per game'] - pts_mean) / (pts_std + 1e-8)

        pts_max = df.groupby(group_keys)['PTS per game'].transform('max')
        df['PTS_conf_share'] = df['PTS per game'] / (pts_max + 1e-8)

        impact_mean = df.groupby(group_keys)['Impact_on_winning'].transform('mean')
        impact_std = df.groupby(group_keys)['Impact_on_winning'].transform('std')

        df['Impact_conf_z'] = (
            (df['Impact_on_winning'] - impact_mean) /
            (impact_std + 1e-8)
        )

        df = df.sort_values(['Player', 'Season Ending Year']).reset_index(drop=True)

        df['AllStar_Last_Year'] = (
            df.groupby('Player')['All Star'].shift(1).fillna(0)
        )

        df['AllStar_last_2'] = (
            df.groupby('Player')['All Star']
            .shift(1)
            .rolling(2)
            .sum()
            .fillna(0)
        )

        return df

    def split(self, df):
        """
            Splits data temporally into train, validation, and test sets.
            This prevents leakage across seasons and ensures that
            evaluation reflects forward prediction.
            Splits:
            - Train: ≤ TRAIN_END
            - Validation: (TRAIN_END, VAL_END]
            - Test: > VAL_END
        """
        train_df = df[df['Season Ending Year'] <= self.cfg.TRAIN_END].reset_index(drop=True)
        val_df = df[
            (df['Season Ending Year'] > self.cfg.TRAIN_END) &
            (df['Season Ending Year'] <= self.cfg.VAL_END)
        ].reset_index(drop=True)
        test_df = df[df['Season Ending Year'] > self.cfg.VAL_END].reset_index(drop=True)

        return train_df, val_df, test_df

    def prepare(self, train_df, val_df, test_df):
        """
            Prepares data for model input.

            Steps:
            1. Separate features, labels, and embedding indices
            2. Impute missing values using training medians
            3. Normalize features using training statistics
            4. Convert all arrays to PyTorch tensors on the target device

            Outputs:
            - X: normalized feature tensors
            - y: labels
            - c, p, s: categorical indices (conference, position, season)

            Notes:
            - Categorical IDs are kept separate for embedding layers
            - Scaling is fit on train only to avoid leakage
            - All tensors are moved to DEVICE for efficient training
            - Works for BOTH raw and engineered datasets
        """

        drop_cols = [
            'All Star', 'Player', 'Season Ending Year',
            'Prev All Stars', 'Conference_East',
            'PosGroup_Backcourt', 'PosGroup_Frontcourt'
        ]

        def split_xy(df):
            optional_cols = ['Conf_ID', 'Pos_ID', 'Season_ID']
            feature_drop = drop_cols + [c for c in optional_cols if c in df.columns]

            X = df.drop(columns=feature_drop)
            y = df['All Star']


            def get_or_default(col, default=0):
                if col in df.columns:
                    return df[col]
                else:
                    return pd.Series(default, index=df.index)

            c = get_or_default('Conf_ID')
            p = get_or_default('Pos_ID')
            s = get_or_default('Season_ID')

            return X, y, c, p, s


        X_train, y_train, c_train, p_train, s_train = split_xy(train_df)
        X_val, y_val, c_val, p_val, s_val = split_xy(val_df)
        X_test, y_test, c_test, p_test, s_test = split_xy(test_df)

        X_train = X_train.fillna(X_train.median())
        X_val   = X_val.fillna(X_train.median())
        X_test  = X_test.fillna(X_train.median())

        X_train = self.scaler.fit_transform(X_train)
        X_val   = self.scaler.transform(X_val)
        X_test  = self.scaler.transform(X_test)

        device = self.cfg.DEVICE

        return (
            torch.tensor(X_train, dtype=torch.float32).to(device),
            torch.tensor(y_train.values, dtype=torch.float32).to(device),
            torch.tensor(c_train.values, dtype=torch.long).to(device),
            torch.tensor(p_train.values, dtype=torch.long).to(device),
            torch.tensor(s_train.values, dtype=torch.long).to(device),

            torch.tensor(X_val, dtype=torch.float32).to(device),
            torch.tensor(y_val.values, dtype=torch.float32).to(device),
            torch.tensor(c_val.values, dtype=torch.long).to(device),
            torch.tensor(p_val.values, dtype=torch.long).to(device),
            torch.tensor(s_val.values, dtype=torch.long).to(device),

            torch.tensor(X_test, dtype=torch.float32).to(device),
            torch.tensor(y_test.values, dtype=torch.float32).to(device),
            torch.tensor(c_test.values, dtype=torch.long).to(device),
            torch.tensor(p_test.values, dtype=torch.long).to(device),
            torch.tensor(s_test.values, dtype=torch.long).to(device),
        )

# %% [markdown]
# The pipeline emphasizes **relative performance within season–conference groups** and **temporal consistency**, which aligns with how All-Star selection is actually determined. It intentionally separates representation (features + embeddings) from interaction (handled later by attention), keeping preprocessing simple while preserving the structure needed for group-based learning.
#
# | Stage        | Component                  | Operation | Meaning |
# |-------------|---------------------------|----------|--------|
# | Load        | CSV → DataFrame           | read_csv | Loads raw season-level player data |
# | Encoding    | Conf_ID, Pos_ID           | int cast | Converts categorical indicators to embeddings |
# | Encoding    | Season_ID                 | year offset | Normalizes season index relative to first year |
# | Feature     | Usage                     | FGA + 0.44·FTA | Proxy for offensive involvement |
# | Feature     | Usage × Win               | Usage * Win% | Scales volume by team success |
# | Feature     | Impact_on_winning         | PTS * Win% | Combines scoring with team performance |
# | Normalize   | PTS_conf_z                | z-score (group) | Measures scoring relative to peers in same season/conf |
# | Normalize   | PTS_conf_share            | share of max | Captures dominance within group |
# | Normalize   | Impact_conf_z             | z-score (group) | Relative impact vs peers |
# | Temporal    | AllStar_Last_Year         | shift(1) | Encodes prior selection |
# | Temporal    | AllStar_last_2            | rolling sum | Captures short-term momentum |
# | Ordering    | Player, Season            | sort | Ensures temporal features are valid |
# | Split       | Train / Val / Test        | time-based | Prevents leakage across seasons |
# | Clean       | Missing values            | median fill | Robust to outliers |
# | Scale       | StandardScaler            | fit/transform | Normalizes feature magnitudes |
# | Structure   | Drop columns              | remove IDs | Prevents leakage from identifiers |
# | Tensorize   | NumPy → Torch             | to(device) | Moves data to GPU/CPU |
# | Output      | (X, y, conf, pos, season) | tuple | Preserves structure for grouped modeling |

# %% [markdown]
# ## Neural Network Model:

# %%
class AllStarNN(nn.Module):
    """
        Neural network for structured All-Star selection.
        Architecture:
        - Tabular features + learned embeddings (conference, position, season)
        - MLP for feature transformation
        - Multi-head self-attention over players within a group
        - Two output heads: starters and reserves
        Design intent:
        - Embeddings encode discrete structure
        - MLP builds player-level representations
        - Attention models competition within a selection pool
        - Separate heads reflect different selection roles (starter vs reserve)
    """
    def __init__(self, input_dim, cfg):
        """
            Initializes model components.
            Args:
                input_dim (int): number of continuous input features
                cfg: configuration object
            Components:
                - Embeddings:
                    conf_emb   → conference (2 → 4)
                    pos_emb    → position (2 → 4)
                    season_emb → season index (≤50 → 8)
                - MLP:
                    Transforms concatenated features into a latent representation
                - Attention:
                    Models interactions between players within the same group
                - Output heads:
                    starter_head → scores for starter selection
                    reserve_head → scores for reserve selection
            Notes:
                - ATTN_DIM defines the shared interaction space
                - LayerNorm + residual connections stabilize attention
        """
        super().__init__()

        self.conf_emb = nn.Embedding(2, 4)
        self.pos_emb = nn.Embedding(2, 4)
        self.season_emb = nn.Embedding(50, 8)
        self.ln1 = nn.LayerNorm(cfg.ATTN_DIM)
        self.ln2 = nn.LayerNorm(cfg.ATTN_DIM)
        self.ff = nn.Sequential(
            nn.Linear(cfg.ATTN_DIM, cfg.ATTN_DIM),
            nn.ReLU(),
            nn.Linear(cfg.ATTN_DIM, cfg.ATTN_DIM)
        )

        prev = input_dim + 16

        layers = []
        for h in cfg.HIDDEN_DIMS:
            layers += [nn.Linear(prev, h), nn.ReLU(), nn.Dropout(cfg.DROPOUT)]
            prev = h

        self.mlp = nn.Sequential(*layers)
        self.to_attn = nn.Linear(prev, cfg.ATTN_DIM)

        self.attn = nn.MultiheadAttention(
            embed_dim=cfg.ATTN_DIM,
            num_heads=cfg.ATTN_HEADS,
            batch_first=True
        )

        self.starter_head = nn.Linear(cfg.ATTN_DIM, 1)
        self.reserve_head = nn.Linear(cfg.ATTN_DIM, 1)

    def forward_group(self, x, conf, pos, season):
        """
            Forward pass over a single (season, conference) group.
                Args:
                    x      : player feature tensor [N, input_dim]
                    conf   : conference indices [N]
                    pos    : position indices [N]
                    season : season indices [N]
                Steps:
                    1. Move inputs to model device
                    2. Concatenate features with embeddings
                    3. Pass through MLP → latent representation
                    4. Project to attention space
                    5. Apply self-attention across players in the group
                    6. Apply feedforward + residual + normalization
                    7. Produce separate scores for starters and reserves
                Returns:
                    starter_scores [N, 1]
                    reserve_scores [N, 1]
            Key idea:
                Scores are not computed independently—each player’s score depends
                on the full group via attention, reflecting competitive selection.
        """
        device = next(self.parameters()).device  

        x = x.to(device)

        conf = conf.to(device=device, dtype=torch.long)
        pos = pos.to(device=device, dtype=torch.long)
        season = season.to(device=device, dtype=torch.long)

        h = torch.cat([
            x,
            self.conf_emb(conf),
            self.pos_emb(pos),
            self.season_emb(season)
        ], dim=1)

        h = self.mlp(h)
        h = self.to_attn(h)
        # Attention operates over players within a group, allowing the model
        # to learn relative importance and competition dynamics.

        h = h.unsqueeze(0)
        attn_out, _ = self.attn(h, h, h)
        h = self.ln1(h + attn_out)

        ff_out = self.ff(h)
        h = self.ln2(h + ff_out)

        h = h.squeeze(0)

        return self.starter_head(h), self.reserve_head(h)
        """
            The model separates representation (MLP) from interaction (attention),
            allowing it to first understand players individually and then evaluate
            them relative to their competition.
        """

# %% [markdown]
# The model first builds a per-player representation, then refines it through attention over the entire group. Final predictions are split into starter and reserve scores, reflecting the structure of the selection process. Attention is applied across players within the same season–conference group, allowing the model to learn relative importance rather than absolute thresholds.
#
# | Stage        | Component            | Operation | Meaning |
# |-------------|----------------------|----------|--------|
# | Input       | Raw Features + IDs   | concat | Combines numeric stats with embeddings |
# | Embedding   | Conf Embedding       | Emb(2 → 4) | Encodes conference context |
# | Embedding   | Position Embedding   | Emb(2 → 4) | Encodes backcourt/frontcourt role |
# | Embedding   | Season Embedding     | Emb(50 → 8) | Captures temporal variation |
# | Backbone    | MLP                  | Linear → ReLU → Dropout | Learns nonlinear feature interactions |
# | Projection  | To Attention Space   | Linear → ATTN_DIM | Maps features into shared interaction space |
# | Interaction | Self-Attention       | MultiheadAttention | Models relationships between players in group |
# | Residual    | Add + LayerNorm      | h + attn(h) | Stabilizes attention updates |
# | Feedforward | FFN                  | Linear → ReLU → Linear | Refines representations post-attention |
# | Residual    | Add + LayerNorm      | h + ff(h) | Further stabilizes representation |
# | Output      | Starter Head         | Linear → 1 | Scores likelihood of starter selection |
# | Output      | Reserve Head         | Linear → 1 | Scores likelihood of reserve selection |
# | Structure   | Group Forward Pass   | batch = group | Processes players jointly, not independently |

# %% [markdown]
# ## Loss Function Definitions:

# %%
def soft_selection(scores, k, temp):
    """
        Differentiable approximation of top-k selection.
        Converts raw scores into a soft allocation over players using a
        temperature-scaled softmax, then scales the distribution to sum to k.
        Args:
            scores : [N] raw logits
            k      : number of selections (e.g., 2 starters, 7 reserves)
            temp   : temperature controlling sharpness
        Returns:
            z : [N] soft selection weights summing to k
        Intuition:
            - As temp ↓ → distribution becomes sharper (closer to hard top-k)
            - As temp ↑ → distribution becomes smoother
        This allows gradients to flow through a top-k-like operation.
    """
    scores = scores.view(-1)
    probs = torch.softmax(scores / temp, dim=0)
    return k * probs 

def selection_loss(scores, labels, k, temp):
    """
        Loss enforcing correct soft top-k selection.
        Compares the model’s soft selection (z) to a normalized target
        distribution over true All-Stars.
        Args:
            scores : [N] model outputs
            labels : [N] binary indicators (1 = All-Star)
            k      : number of selections
            temp   : softmax temperature
        Returns:
            scalar loss
        Mechanism:
            - z = soft_selection(scores)
            - target = evenly distributes k mass over true positives
            - loss = mean squared error between z and target
        Notes:
            - If no positives exist in a group, loss is zero
            - Encourages correct allocation of selection mass, not just ranking
        Key idea:
            The model is trained to "spend" its k selections on the correct players.
    """
    scores = scores.view(-1)
    labels = labels.view(-1)

    if labels.sum() == 0:
        return torch.zeros(1, device=scores.device)

    z = soft_selection(scores, k, temp)

    target = k * labels / (labels.sum() + 1e-8)

    return torch.mean((z - target) ** 2)

def pairwise_loss(scores, labels, margin=0.01):
    """
        Margin-based pairwise ranking loss.
        Encourages positive examples to score higher than negative ones
        by at least a fixed margin.
        Args:
            scores : [N] model outputs
            labels : [N] binary indicators
            margin : minimum desired separation
        Returns:
            scalar loss
        Mechanism:
            - For all (pos, neg) pairs:
                loss = max(0, margin - (score_pos - score_neg))
            - Penalizes cases where positives do not sufficiently outrank negatives
        Notes:
            - Returns zero if no valid pairs exist
            - Operates within each group independently
        Key idea:
            Enforces relative ordering, complementing selection_loss which
            enforces allocation.
    """
    scores = scores.view(-1)
    labels = labels.view(-1)

    pos = scores[labels == 1]
    neg = scores[labels == 0]

    if len(pos) == 0 or len(neg) == 0:
        return torch.zeros(1, device=scores.device)

    diff = pos.unsqueeze(1) - neg.unsqueeze(0)
    return torch.relu(margin - diff).mean()

    """
        These losses serve complementary roles:
        - selection_loss → enforces *who gets selected*
        - pairwise_loss  → enforces *who ranks above whom*

        Together, they align the model with both the combinatorial structure
        (top-k selection) and the ordinal structure (ranking) of the task.
    """

# %% [markdown]
# $$
# \mathcal{L}
# =\left(
# \lambda_{\text{BCE}} \cdot \mathcal{L}_{\text{BCE}} \right)
# +
# \left(\lambda_{\text{pair}} \cdot \mathcal{L}_{\text{pair}}\right)
# +
# \mathcal{L}_{\text{top-k}}
# $$
#
# Rather than predicting independent probabilities, the model is trained to allocate a fixed selection budget across players and rank true All-Stars above others within each group.
#
# The loss combines a soft top-k selection objective with a pairwise ranking constraint. The selection term ensures the correct number of players are chosen, while the pairwise term enforces relative ordering between All-Stars and non-All-Stars.
#
# | Component     | Function          | Operation | Meaning |
# |--------------|------------------|----------|--------|
# | Selection    | Soft Selection    | softmax(scores / temp) | Converts scores into a soft top-k distribution |
# | Selection    | Scaling           | k · probs | Ensures total mass equals number of selections |
# | Selection    | Target Distribution | k · labels / sum(labels) | Ground-truth allocation over true All-Stars |
# | Selection    | Loss              | MSE(z, target) | Penalizes deviation from correct selection proportions |
# | Ranking      | Pairwise Loss     | max(0, margin − (pos − neg)) | Enforces All-Star scores > non-All-Star scores |
# | Ranking      | Margin            | 0.01 | Minimum separation between positive and negative scores |
# | Stability    | Temperature       | score / temp | Controls sharpness of selection distribution |
# | Edge Case    | Empty Group       | return 0 | Avoids invalid loss when no positives exist |

# %% [markdown]
# ## Training Loop Definition:

# %%
class Trainer:
    """
        Training loop for the neural network model.

        Combines multiple objectives to align training with the structured
        All-Star selection task:
        - soft top-k selection (who gets chosen)
        - pairwise ranking (who beats whom)
        - BCE calibration (probability quality)
        - structural constraints (position balance, role separation)

        Extended with hyperparameter tuning (weight decay sweep)
        to match the SVM experimental framework.
    """

    def __init__(self, cfg):
        """
            Initializes trainer with configuration and loss functions.
            Uses BCEWithLogitsLoss for stable probability calibration.
        """
        self.cfg = cfg
        self.bce = nn.BCEWithLogitsLoss()


    def train(self, model,
              X_train, y_train, c_train, p_train, s_train,
              X_val, y_val, c_val, p_val, s_val,
              train_groups, val_groups,
              weight_decay):
        """
            Trains the model over grouped data.

            Args:
                model        : neural network
                X_*, y_*     : features and labels
                c_*, p_*, s_ : categorical indices
                *_groups     : grouped indices (per season, conference)
                weight_decay : regularization strength (swept)

            Training is performed per group to preserve selection structure.
        """
        device = self.cfg.DEVICE
        model = model.to(device)

        optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=self.cfg.LR,
            weight_decay=weight_decay
        )

        for epoch in range(self.cfg.EPOCHS):
            model.train()
            total_loss = 0

            for idx in train_groups:
                Xg = X_train[idx]
                yg = y_train[idx]
                cg = c_train[idx]
                pg = p_train[idx]
                sg = s_train[idx]

                bc = (pg == 1)
                fc = (pg == 0)

                optimizer.zero_grad()

                s, r = model.forward_group(Xg, cg, pg, sg)

                loss = torch.zeros(1, device=Xg.device)

                # ===== Starter constraints =====
                if bc.sum() > 0:
                    loss += selection_loss(s[bc], yg[bc], k=2, temp=self.cfg.TOPK_TEMP)
                    loss += self.cfg.PAIRWISE_WEIGHT * pairwise_loss(s[bc], yg[bc])

                if fc.sum() > 0:
                    loss += selection_loss(s[fc], yg[fc], k=3, temp=self.cfg.TOPK_TEMP)
                    loss += self.cfg.PAIRWISE_WEIGHT * pairwise_loss(s[fc], yg[fc])

                # ===== Reserve constraints =====
                loss += selection_loss(r, yg, k=7, temp=self.cfg.TOPK_TEMP)
                loss += self.cfg.PAIRWISE_WEIGHT * pairwise_loss(r, yg)

                # ===== Calibration =====
                combined_scores = (s + r).squeeze()
                loss += self.cfg.BCE_WEIGHT * self.bce(combined_scores, yg)

                # ===== Positional balance =====
                z_total = soft_selection(combined_scores, k=12, temp=self.cfg.TOPK_TEMP)
                target_bc = 2 / 12
                actual_bc = z_total[pg == 1].sum() / 12
                loss += 0.005 * (actual_bc - target_bc) ** 2

                # ===== Role separation =====
                z_starters = torch.zeros_like(s.squeeze())

                if bc.sum() > 0:
                    z_starters[bc] = soft_selection(s[bc], k=2, temp=self.cfg.TOPK_TEMP)

                if fc.sum() > 0:
                    z_starters[fc] = soft_selection(s[fc], k=3, temp=self.cfg.TOPK_TEMP)

                z_reserves = soft_selection(r.squeeze(), k=7, temp=self.cfg.TOPK_TEMP)
                loss += 0.005 * (z_starters * z_reserves).sum()

                loss.backward()
                optimizer.step()

                total_loss += loss.item()

            # ===== Validation AUC =====
            model.eval()
            scores = torch.zeros_like(y_val)

            with torch.no_grad():
                for idx in val_groups:
                    s_, r_ = model.forward_group(
                        X_val[idx], c_val[idx], p_val[idx], s_val[idx]
                    )
                    scores[idx] = (0.3 * s_ + 0.7 * r_).squeeze()

            auc = roc_auc_score(y_val.cpu(), scores.cpu())

            print(f"Epoch {epoch+1:03d} | Loss {total_loss:.2f} | Val AUC {auc:.4f}")

        return model
    
    def structured_selection(self, df):
        """
            Applies deterministic roster construction based on predicted scores.
        """
        df = df.copy()
        df['pred'] = 0

        for (season, conf), group in df.groupby(['Season Ending Year', 'Conference_East']):
            bc = group[group['PosGroup_Backcourt'] == 1]
            fc = group[group['PosGroup_Backcourt'] == 0]

            starters = pd.concat([
                bc.sort_values('prob', ascending=False).head(2),
                fc.sort_values('prob', ascending=False).head(3)
            ])

            remaining = group.drop(index=starters.index)
            reserves = remaining.sort_values('prob', ascending=False).head(7)

            selected = pd.concat([starters, reserves])
            df.loc[selected.index, 'pred'] = 1

        return df

    def evaluate_val(self, model,
                     X_val, y_val, c_val, p_val, s_val,
                     val_groups, val_df):
        """
            Computes validation metrics:
                - AUC (ranking quality)
                - Top-K Recall (selection quality)
        """
        device = self.cfg.DEVICE
        model.eval()

        scores = torch.zeros(len(val_df), device=device)

        with torch.no_grad():
            for idx in val_groups:
                s_, r_ = model.forward_group(
                    X_val[idx], c_val[idx], p_val[idx], s_val[idx]
                )
                scores[idx] = torch.sigmoid((0.3*s_ + 0.7*r_).squeeze())

        scores_np = scores.cpu().numpy()
        y_np = y_val.cpu().numpy()

        auc = roc_auc_score(y_np, scores_np)

        temp_df = val_df.copy()
        temp_df['prob'] = scores_np
        temp_df = self.structured_selection(temp_df)

        selected_correct = ((temp_df['pred'] == 1) & (y_np == 1)).sum()
        topk = selected_correct / (y_np.sum() + 1e-8)

        return auc, topk

    def tune(self, model_fn,
             X_train, y_train, c_train, p_train, s_train,
             X_val, y_val, c_val, p_val, s_val,
             train_groups, val_groups,
             train_df, val_df):
        """
            Sweeps weight decay values and selects best model.

            Selection objective:
                1. Maximize Top-K Recall (primary)
                2. Break ties using AUC
        """
        results = []

        for wd in self.cfg.WD_VALUES:
            print(f"\n=== Training with weight_decay={wd:.6e} ===")

            model = model_fn()

            trained_model = self.train(
                model,
                X_train, y_train, c_train, p_train, s_train,
                X_val, y_val, c_val, p_val, s_val,
                train_groups, val_groups,
                weight_decay=wd
            )

            auc, topk = self.evaluate_val(
                trained_model,
                X_val, y_val, c_val, p_val, s_val,
                val_groups, val_df
            )

            results.append((wd, auc, topk, trained_model))

            print(f"WD={wd:.6e} | AUC={auc:.4f} | TopK={topk:.4f}")

        best_entry = sorted(results, key=lambda x: (x[2], x[1]), reverse=True)[0]

        best_wd = best_entry[0]
        best_model = best_entry[3]

        print(f"\nBest weight decay: {best_wd}")
        print(f"Best Validation TopK: {best_entry[2]:.4f}")

        return best_model, best_wd, results
        """
            The training objective is explicitly structured to match the task:
            - selection_loss → enforces top-k constraints
            - pairwise_loss  → enforces relative ranking
            - BCE            → maintains calibration
            - penalties      → enforce roster structure
            This avoids treating the problem as independent classification
            and instead models it as constrained, grouped selection.
        """

# %% [markdown]
# The objective is not purely predictive. It enforces combinatorial structure (top-k selection), relative ordering (pairwise ranking), and global constraints (roster composition) during training. Training operates at the group level, optimizing a structured objective that combines selection constraints, ranking consistency, and probabilistic calibration. The model is explicitly guided to produce valid All-Star rosters rather than independent predictions.
#
# | Component        | Step                  | Operation | Meaning |
# |------------------|----------------------|----------|--------|
# | Optimization     | Optimizer            | AdamW | Adaptive optimization with weight decay for stability |
# | Optimization     | Learning Rate        | cfg.LR | Controls update step size |
# | Optimization     | Weight Decay         | cfg.WEIGHT_DECAY | Prevents overfitting via parameter shrinkage |
# | Training Loop    | Group Iteration      | loop over (season, conference) | Ensures learning happens within selection pools |
# | Forward Pass     | Dual Heads           | (s, r) = model(...) | Produces starter and reserve scores |
# | Selection Loss   | Starters (BC/FC)     | top-k MSE | Enforces correct number of starters per position group |
# | Selection Loss   | Reserves             | top-k MSE | Enforces correct number of reserves |
# | Ranking Loss     | Pairwise             | hinge(pos − neg) | Forces All-Stars to rank above non-All-Stars |
# | Calibration      | BCE Loss             | BCE(s + r, y) | Maintains probabilistic interpretability |
# | Constraint       | Position Balance     | (actual − target)^2 | Encourages correct backcourt/frontcourt proportions |
# | Constraint       | Overlap Penalty      | sum(z_starters · z_reserves) | Prevents selecting same player twice |
# | Regularization   | Loss Weights         | weighted sum | Balances selection, ranking, and calibration |
# | Backprop         | Gradient Step        | loss.backward() + step() | Updates model parameters |
# | Validation       | Score Aggregation    | 0.3·s + 0.7·r | Combines starter/reserve signals |
# | Evaluation       | Metric               | AUC | Measures ranking quality |

# %% [markdown]
# ## Evaluation Function Definition:

# %%
def evaluate(model, X_test, y_test, c_test, p_test, s_test, test_df, cfg):
    """
        Evaluates the trained model under structured selection constraints.
        This function performs:
            1. Group-wise inference (season, conference)
            2. Score aggregation (starter + reserve heads)
            3. Hard roster selection (top-12 with positional constraints)
            4. Metric computation at global and grouped levels
        Args:
            model   : trained neural network
            X_test  : feature tensor
            y_test  : ground truth labels
            c_test  : conference indices
            p_test  : position indices
            s_test  : season indices
            test_df : original dataframe (for grouping + metadata)
            cfg     : configuration object
    """
    device = cfg.DEVICE
    model.eval()

    test_df = test_df.reset_index(drop=True)
    scores = torch.zeros(len(test_df), device=device)

    with torch.no_grad():
        """
            Inference is performed per group to preserve competition structure.
            Scores are computed as a weighted combination:
                0.3 * starter_score + 0.7 * reserve_score
            This reflects that most selections are reserves (7 vs 5 starters),
            while still incorporating starter importance.
        """
        groups = build_group_indices(test_df, device)

        for idx in groups:
            """
                Applies hard roster constraints:
                Per (season, conference):
                - Select top 2 backcourt starters
                - Select top 3 frontcourt starters
                - Select top 7 remaining players as reserves
                This converts continuous scores into discrete roster decisions.
            """
            s_, r_ = model.forward_group(
                X_test[idx],
                c_test[idx],
                p_test[idx],
                s_test[idx]
            )
            scores[idx] = torch.sigmoid((0.3*s_ + 0.7*r_).squeeze())

    scores_np = scores.cpu().numpy()
    y_np = y_test.cpu().numpy()
    test_df['score'] = scores_np
    test_df['pred'] = 0

    for (season, conf), group in test_df.groupby(['Season Ending Year', 'Conference_East']):
        
        bc = group[group['PosGroup_Backcourt'] == 1]
        fc = group[group['PosGroup_Backcourt'] == 0]

        starters = pd.concat([
            bc.sort_values('score', ascending=False).head(2),
            fc.sort_values('score', ascending=False).head(3)
        ])

        remaining = group.drop(index=starters.index)
        reserves = remaining.sort_values('score', ascending=False).head(7)

        selected = pd.concat([starters, reserves])
        test_df.loc[selected.index, 'pred'] = 1

    y_pred_global = test_df['pred'].values
    """
        Global metrics evaluate overall performance:
            - AUC: ranking quality (independent of selection threshold)
            - Accuracy: correctness of final selections
            - Precision: fraction of selected players who are true All-Stars
            - Recall: fraction of true All-Stars selected
            - F1: balance between precision and recall
    """


    print("\n=== FINAL RESULTS ===")
    print("AUC:", roc_auc_score(y_np, scores_np))
    print("Accuracy:", accuracy_score(y_np, y_pred_global))
    print("Precision:", precision_score(y_np, y_pred_global, zero_division=0))
    print("Recall:", recall_score(y_np, y_pred_global, zero_division=0))
    print("F1:", f1_score(y_np, y_pred_global, zero_division=0))

    print("\n=== Per-Season (Conference Split) ===")

    season_conf_metrics = []

    for (season, conf), group in test_df.groupby(['Season Ending Year', 'Conference_East']):
        """
            Per (season, conference) metrics assess consistency across groups.
            Additional metrics:
                - TopK Recall: fraction of true All-Stars captured
                - Top12 Accuracy: quality of selected roster (precision at k=12)
            These better reflect the structured nature of the task than global metrics alone.
        """
        y_g = group['All Star'].values
        p_g = group['pred'].values
        score_g = group['score'].values

        auc = roc_auc_score(y_g, score_g)
        acc = accuracy_score(y_g, p_g)
        prec = precision_score(y_g, p_g, zero_division=0)
        rec = recall_score(y_g, p_g, zero_division=0)
        f1 = f1_score(y_g, p_g, zero_division=0)

        true_allstars = y_g.sum()
        selected_correct = ((p_g == 1) & (y_g == 1)).sum()
        topk_recall = selected_correct / (true_allstars + 1e-8)

        total_selected = p_g.sum()
        top12_acc = selected_correct / (total_selected + 1e-8)

        season_conf_metrics.append((auc, acc, prec, rec, f1, topk_recall, top12_acc))

        print(
            f"{season} Conf {conf} | "
            f"AUC {auc:.4f} | "
            f"Acc {acc:.3f} | "
            f"P {prec:.3f} | R {rec:.3f} | F1 {f1:.3f} | "
            f"Top 12 Recall {topk_recall:.3f} | Top 12 Accuracy {top12_acc:.3f}"
        )

    print("\n=== Per-Season (Overall) ===")
    season_metrics = []
    for season, group in test_df.groupby('Season Ending Year'):
        """
            Per-season metrics aggregate performance across conferences.
            This highlights temporal stability and identifies year-specific variation.
        """
        y_g = group['All Star'].values
        p_g = group['pred'].values
        score_g = group['score'].values

        auc = roc_auc_score(y_g, score_g)
        acc = accuracy_score(y_g, p_g)
        prec = precision_score(y_g, p_g, zero_division=0)
        rec = recall_score(y_g, p_g, zero_division=0)
        f1 = f1_score(y_g, p_g, zero_division=0)

        true_allstars = y_g.sum()
        selected_correct = ((p_g == 1) & (y_g == 1)).sum()
        topk_recall = selected_correct / (true_allstars + 1e-8)

        total_selected = p_g.sum()
        top12_acc = selected_correct / (total_selected + 1e-8)

        season_metrics.append((auc, acc, prec, rec, f1, topk_recall, top12_acc))

        print(
            f"{season} | "
            f"AUC {auc:.4f} | "
            f"Acc {acc:.3f} | "
            f"P {prec:.3f} | R {rec:.3f} | F1 {f1:.3f} | "
            f"Top 12 Recall {topk_recall:.3f} | Top 12 Accuracy {top12_acc:.3f}"
        )

    season_metrics = np.array(season_metrics)
    """
        Average metrics summarize performance across seasons.
        This provides a stable estimate of model behavior under
        realistic selection constraints.
    """
    print("\n=== Avg Per-Season Metrics ===")
    print("AUC              :", season_metrics[:, 0].mean())
    print("Accuracy         :", season_metrics[:, 1].mean())
    print("Precision        :", season_metrics[:, 2].mean())
    print("Recall           :", season_metrics[:, 3].mean())
    print("F1               :", season_metrics[:, 4].mean())
    print("Top 12 Recall    :", season_metrics[:, 5].mean())
    print("Top 12 Accuracy  :", season_metrics[:, 6].mean())

    """
        Evaluation mirrors the true task: ranking players is not sufficient—
        the model must also construct valid rosters under fixed constraints.
    """

# %% [markdown]
# The model is not evaluated as a standard classifier. Performance is measured after enforcing the discrete selection constraint, making the metrics reflect actual roster construction rather than independent predictions. Evaluation mirrors the training structure: predictions are made within each (season, conference) group and converted into a valid 12-player roster. Metrics are reported both globally and at the group level to capture ranking quality and selection accuracy.
#
# | Component        | Step                  | Operation | Meaning |
# |------------------|----------------------|----------|--------|
# | Inference        | Group Forward Pass   | (s, r) = model(...) | Computes starter and reserve scores per group |
# | Score Aggregation| Weighted Combine     | 0.3·s + 0.7·r | Prioritizes reserve signal while retaining starter signal |
# | Calibration      | Sigmoid              | σ(score) | Converts logits into probabilities |
# | Grouping         | Selection Pools      | (season, conference) | Ensures predictions are made within valid All-Star pools |
# | Selection        | Starters             | top-2 BC, top-3 FC | Enforces positional constraints |
# | Selection        | Reserves             | top-7 remaining | Completes 12-player roster |
# | Prediction       | Binary Labels        | pred ∈ {0,1} | Marks selected players as All-Stars |
# | Global Metric    | AUC                  | roc_auc | Measures ranking quality over all players |
# | Global Metric    | Accuracy             | correct / total | Measures overall classification correctness |
# | Global Metric    | Precision            | TP / (TP + FP) | Measures selection quality |
# | Global Metric    | Recall               | TP / (TP + FN) | Measures coverage of true All-Stars |
# | Global Metric    | F1 Score             | harmonic mean | Balances precision and recall |
# | Group Metric     | Per (Season, Conf)   | metrics per group | Evaluates local selection performance |
# | Group Metric     | Per Season           | metrics per season | Evaluates yearly consistency |
# | Ranking Metric   | Top-K Recall         | correct / true | Fraction of true All-Stars selected |
# | Selection Metric | Top-12 Accuracy      | correct / 12 | Precision within selected roster |
# | Aggregation      | Mean Metrics         | average over seasons | Stabilizes evaluation across years |

# %% [markdown]
# ## Runtime:

# %%
"""
End-to-end training pipeline for the neural network model.
Workflow:
    1. Initialize configuration and fix randomness
    2. Load and preprocess data
    3. Perform time-based train / validation / test split
    4. Convert data into tensors and structured inputs
    5. Build group indices (season, conference) for grouped training
    6. Initialize model and apply Kaiming weight initialization
    7. Train model using structured losses and validation monitoring
Key design choices:
    - Grouped training:
        Each forward pass operates on a full (season, conference) pool,
        allowing the model to learn selection dynamics rather than
        independent predictions.
    - Feature decomposition:
        Inputs are split into:
            - continuous features (X)
            - categorical embeddings (conference, position, season)
    - Weight initialization:
        He initialization stabilizes training for deep ReLU networks.
    - Structured optimization:
        Training combines:
            - soft top-k selection losses (roster constraints)
            - pairwise ranking losses (relative ordering)
            - BCE loss (global calibration)
    - Validation:
        AUC is tracked per epoch to monitor ranking quality.
Outputs:
    - Trained neural network model
    - Epoch-wise loss and validation AUC trajectory
Notes:
    - Training is fully GPU-compatible if available
    - Group indices are essential: they define the competitive context
    - Model learns both "who is good" and "who beats whom" within a pool
"""
# Out:
# '\nEnd-to-end training pipeline for the neural network model.\nWorkflow:\n    1. Initialize configuration and fix randomness\n    2. Load and preprocess data\n    3. Perform time-based train / validation / test split\n    4. Convert data into tensors and structured inputs\n    5. Build group indices (season, conference) for grouped training\n    6. Initialize model and apply Kaiming weight initialization\n    7. Train model using structured losses and validation monitoring\nKey design choices:\n    - Grouped training:\n        Each forward pass operates on a full (season, conference) pool,\n        allowing the model to learn selection dynamics rather than\n        independent predictions.\n    - Feature decomposition:\n        Inputs are split into:\n            - continuous features (X)\n            - categorical embeddings (conference, position, season)\n    - Weight initialization:\n        He initialization stabilizes training for deep ReLU networks.\n    - Structured optimization:\n        Training combines:\n            - soft top-k selection losses (roster constraints)\n            - pairwise ranking losses (relative ordering)\n            - BCE loss (global calibration)\n    - Validation:\n        AUC is tracked per epoch to monitor ranking quality.\nOutputs:\n    - Trained neural network model\n    - Epoch-wise loss and validation AUC trajectory\nNotes:\n    - Training is fully GPU-compatible if available\n    - Group indices are essential: they define the competitive context\n    - Model learns both "who is good" and "who beats whom" within a pool\n'

# %%
cfg = Config()
set_seed(cfg.SEED)

trainer = Trainer(cfg)

results_nn = []

for is_raw_data in (True, False):

    data_type = "RAW" if is_raw_data else "ENGINEERED"
    print(f"\n\n==============================")
    print(f"RUNNING NN ON {data_type} DATA")
    print(f"==============================")

    pipeline = DataPipeline(cfg)

    if is_raw_data:
        df = pd.read_csv(DATA_PATH)
    else:
        df = pipeline.load(DATA_PATH)

    train_df, val_df, test_df = pipeline.split(df)

    data = pipeline.prepare(train_df, val_df, test_df)

    (X_train, y_train, c_train, p_train, s_train,
     X_val, y_val, c_val, p_val, s_val,
     X_test, y_test, c_test, p_test, s_test) = data

    train_groups = build_group_indices(train_df, cfg.DEVICE)
    val_groups   = build_group_indices(val_df, cfg.DEVICE)

    def model_fn():
        model = AllStarNN(X_train.shape[1], cfg)

        def init_weights(m):
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

        model.apply(init_weights)
        return model

    model, best_wd, history = trainer.tune(
        model_fn,
        X_train, y_train, c_train, p_train, s_train,
        X_val, y_val, c_val, p_val, s_val,
        train_groups, val_groups,
        train_df, val_df
    )

    sorted_history = sorted(history, key=lambda h: (h[2], h[1]), reverse=True)
    best_trial = sorted_history[0]

    final_auc = best_trial[1]
    final_topk = best_trial[2]

    results_nn.append({
        "name": f"NN_{data_type}",
        "data_type": data_type,
        "model": model,
        "best_wd": best_wd,
        "auc": final_auc,
        "topk": final_topk,
        "tuning_history": history,  
        "X_test": X_test,
        "y_test": y_test,
        "c_test": c_test,
        "p_test": p_test,
        "s_test": s_test,
        "test_df": test_df
    })

    print(f"\n{data_type} RESULT:")
    print(f"Best WD: {best_wd}")
    print(f"Val AUC: {final_auc:.4f}")
    print(f"Val TopK: {final_topk:.4f}")
# Out:
# ==============================
# RUNNING NN ON RAW DATA
# ==============================
#
# === Training with weight_decay=1.000000e-06 ===
# Epoch 001 | Loss 11.60 | Val AUC 0.9688
# Epoch 002 | Loss 7.71 | Val AUC 0.9767
# Epoch 003 | Loss 7.10 | Val AUC 0.9797
# Epoch 004 | Loss 6.71 | Val AUC 0.9809
# Epoch 005 | Loss 6.34 | Val AUC 0.9822
# Epoch 006 | Loss 6.12 | Val AUC 0.9826
# Epoch 007 | Loss 6.02 | Val AUC 0.9827
# Epoch 008 | Loss 5.76 | Val AUC 0.9831
# Epoch 009 | Loss 5.64 | Val AUC 0.9832
# Epoch 010 | Loss 5.49 | Val AUC 0.9829
# Epoch 011 | Loss 5.46 | Val AUC 0.9833
# Epoch 012 | Loss 5.41 | Val AUC 0.9838
# Epoch 013 | Loss 5.28 | Val AUC 0.9845
# Epoch 014 | Loss 5.28 | Val AUC 0.9847
# Epoch 015 | Loss 5.10 | Val AUC 0.9848
# Epoch 016 | Loss 5.02 | Val AUC 0.9850
# Epoch 017 | Loss 5.07 | Val AUC 0.9847
# Epoch 018 | Loss 4.93 | Val AUC 0.9849
# Epoch 019 | Loss 4.86 | Val AUC 0.9851
# Epoch 020 | Loss 4.84 | Val AUC 0.9850
# Epoch 021 | Loss 4.87 | Val AUC 0.9853
# Epoch 022 | Loss 4.91 | Val AUC 0.9853
# Epoch 023 | Loss 4.77 | Val AUC 0.9858
# Epoch 024 | Loss 4.70 | Val AUC 0.9858
# Epoch 025 | Loss 4.77 | Val AUC 0.9861
# Epoch 026 | Loss 4.62 | Val AUC 0.9858
# Epoch 027 | Loss 4.69 | Val AUC 0.9856
# Epoch 028 | Loss 4.65 | Val AUC 0.9862
# Epoch 029 | Loss 4.64 | Val AUC 0.9858
# Epoch 030 | Loss 4.64 | Val AUC 0.9865
# Epoch 031 | Loss 4.57 | Val AUC 0.9861
# Epoch 032 | Loss 4.44 | Val AUC 0.9862
# Epoch 033 | Loss 4.51 | Val AUC 0.9858
# Epoch 034 | Loss 4.46 | Val AUC 0.9858
# Epoch 035 | Loss 4.45 | Val AUC 0.9861
# Epoch 036 | Loss 4.47 | Val AUC 0.9861
# Epoch 037 | Loss 4.29 | Val AUC 0.9863
# Epoch 038 | Loss 4.28 | Val AUC 0.9867
# Epoch 039 | Loss 4.33 | Val AUC 0.9859
# Epoch 040 | Loss 4.30 | Val AUC 0.9862
# Epoch 041 | Loss 4.32 | Val AUC 0.9866
# Epoch 042 | Loss 4.43 | Val AUC 0.9865
# Epoch 043 | Loss 4.33 | Val AUC 0.9865
# Epoch 044 | Loss 4.26 | Val AUC 0.9866
# Epoch 045 | Loss 4.34 | Val AUC 0.9869
# Epoch 046 | Loss 4.25 | Val AUC 0.9869
# Epoch 047 | Loss 4.27 | Val AUC 0.9856
# Epoch 048 | Loss 4.22 | Val AUC 0.9862
# Epoch 049 | Loss 4.20 | Val AUC 0.9863
# Epoch 050 | Loss 4.16 | Val AUC 0.9862
# Epoch 051 | Loss 4.15 | Val AUC 0.9859
# Epoch 052 | Loss 4.09 | Val AUC 0.9854
# Epoch 053 | Loss 4.19 | Val AUC 0.9869
# Epoch 054 | Loss 4.16 | Val AUC 0.9862
# Epoch 055 | Loss 4.14 | Val AUC 0.9854
# Epoch 056 | Loss 4.20 | Val AUC 0.9858
# Epoch 057 | Loss 4.13 | Val AUC 0.9852
# Epoch 058 | Loss 4.09 | Val AUC 0.9850
# Epoch 059 | Loss 4.17 | Val AUC 0.9857
# Epoch 060 | Loss 4.09 | Val AUC 0.9857
# Epoch 061 | Loss 4.14 | Val AUC 0.9863
# Epoch 062 | Loss 4.00 | Val AUC 0.9864
# Epoch 063 | Loss 4.03 | Val AUC 0.9859
# Epoch 064 | Loss 3.98 | Val AUC 0.9856
# Epoch 065 | Loss 3.99 | Val AUC 0.9859
# Epoch 066 | Loss 4.03 | Val AUC 0.9861
# Epoch 067 | Loss 3.89 | Val AUC 0.9852
# Epoch 068 | Loss 4.00 | Val AUC 0.9854
# Epoch 069 | Loss 3.88 | Val AUC 0.9857
# Epoch 070 | Loss 3.99 | Val AUC 0.9854
# Epoch 071 | Loss 3.90 | Val AUC 0.9854
# Epoch 072 | Loss 3.85 | Val AUC 0.9851
# Epoch 073 | Loss 3.85 | Val AUC 0.9847
# Epoch 074 | Loss 3.90 | Val AUC 0.9853
# Epoch 075 | Loss 3.89 | Val AUC 0.9852
# Epoch 076 | Loss 3.87 | Val AUC 0.9854
# Epoch 077 | Loss 3.83 | Val AUC 0.9849
# Epoch 078 | Loss 3.93 | Val AUC 0.9861
# Epoch 079 | Loss 3.96 | Val AUC 0.9865
# Epoch 080 | Loss 3.78 | Val AUC 0.9861
# WD=1.000000e-06 | AUC=0.9861 | TopK=0.7658
#
# === Training with weight_decay=2.782559e-06 ===
# Epoch 001 | Loss 14.80 | Val AUC 0.9629
# Epoch 002 | Loss 8.94 | Val AUC 0.9718
# Epoch 003 | Loss 7.93 | Val AUC 0.9754
# Epoch 004 | Loss 7.29 | Val AUC 0.9768
# Epoch 005 | Loss 6.99 | Val AUC 0.9774
# Epoch 006 | Loss 6.54 | Val AUC 0.9788
# Epoch 007 | Loss 6.49 | Val AUC 0.9794
# Epoch 008 | Loss 6.21 | Val AUC 0.9796
# Epoch 009 | Loss 6.13 | Val AUC 0.9809
# Epoch 010 | Loss 6.00 | Val AUC 0.9813
# Epoch 011 | Loss 5.88 | Val AUC 0.9824
# Epoch 012 | Loss 5.68 | Val AUC 0.9821
# Epoch 013 | Loss 5.52 | Val AUC 0.9825
# Epoch 014 | Loss 5.47 | Val AUC 0.9832
# Epoch 015 | Loss 5.48 | Val AUC 0.9833
# Epoch 016 | Loss 5.45 | Val AUC 0.9844
# Epoch 017 | Loss 5.42 | Val AUC 0.9843
# Epoch 018 | Loss 5.40 | Val AUC 0.9844
# Epoch 019 | Loss 5.18 | Val AUC 0.9845
# Epoch 020 | Loss 5.30 | Val AUC 0.9846
# Epoch 021 | Loss 5.22 | Val AUC 0.9849
# Epoch 022 | Loss 4.99 | Val AUC 0.9851
# Epoch 023 | Loss 5.06 | Val AUC 0.9851
# Epoch 024 | Loss 4.95 | Val AUC 0.9855
# Epoch 025 | Loss 4.91 | Val AUC 0.9859
# Epoch 026 | Loss 4.98 | Val AUC 0.9856
# Epoch 027 | Loss 5.00 | Val AUC 0.9853
# Epoch 028 | Loss 4.90 | Val AUC 0.9856
# Epoch 029 | Loss 4.81 | Val AUC 0.9854
# Epoch 030 | Loss 4.86 | Val AUC 0.9856
# Epoch 031 | Loss 4.78 | Val AUC 0.9861
# Epoch 032 | Loss 4.90 | Val AUC 0.9855
# Epoch 033 | Loss 4.77 | Val AUC 0.9858
# Epoch 034 | Loss 4.72 | Val AUC 0.9856
# Epoch 035 | Loss 4.70 | Val AUC 0.9856
# Epoch 036 | Loss 4.79 | Val AUC 0.9861
# Epoch 037 | Loss 4.64 | Val AUC 0.9861
# Epoch 038 | Loss 4.66 | Val AUC 0.9855
# Epoch 039 | Loss 4.53 | Val AUC 0.9861
# Epoch 040 | Loss 4.65 | Val AUC 0.9862
# Epoch 041 | Loss 4.63 | Val AUC 0.9863
# Epoch 042 | Loss 4.53 | Val AUC 0.9864
# Epoch 043 | Loss 4.52 | Val AUC 0.9867
# Epoch 044 | Loss 4.55 | Val AUC 0.9866
# Epoch 045 | Loss 4.57 | Val AUC 0.9868
# Epoch 046 | Loss 4.42 | Val AUC 0.9868
# Epoch 047 | Loss 4.40 | Val AUC 0.9862
# Epoch 048 | Loss 4.43 | Val AUC 0.9863
# Epoch 049 | Loss 4.56 | Val AUC 0.9860
# Epoch 050 | Loss 4.44 | Val AUC 0.9868
# Epoch 051 | Loss 4.45 | Val AUC 0.9866
# Epoch 052 | Loss 4.40 | Val AUC 0.9867
# Epoch 053 | Loss 4.37 | Val AUC 0.9868
# Epoch 054 | Loss 4.34 | Val AUC 0.9871
# Epoch 055 | Loss 4.29 | Val AUC 0.9862
# Epoch 056 | Loss 4.37 | Val AUC 0.9858
# Epoch 057 | Loss 4.28 | Val AUC 0.9855
# Epoch 058 | Loss 4.22 | Val AUC 0.9853
# Epoch 059 | Loss 4.19 | Val AUC 0.9855
# Epoch 060 | Loss 4.30 | Val AUC 0.9846
# Epoch 061 | Loss 4.22 | Val AUC 0.9845
# Epoch 062 | Loss 4.20 | Val AUC 0.9852
# Epoch 063 | Loss 4.20 | Val AUC 0.9855
# Epoch 064 | Loss 4.16 | Val AUC 0.9852
# Epoch 065 | Loss 4.11 | Val AUC 0.9853
# Epoch 066 | Loss 4.22 | Val AUC 0.9854
# Epoch 067 | Loss 4.20 | Val AUC 0.9855
# Epoch 068 | Loss 4.01 | Val AUC 0.9861
# Epoch 069 | Loss 4.04 | Val AUC 0.9852
# Epoch 070 | Loss 4.05 | Val AUC 0.9859
# Epoch 071 | Loss 4.01 | Val AUC 0.9864
# Epoch 072 | Loss 4.04 | Val AUC 0.9868
# Epoch 073 | Loss 4.08 | Val AUC 0.9865
# Epoch 074 | Loss 4.08 | Val AUC 0.9863
# Epoch 075 | Loss 4.14 | Val AUC 0.9860
# Epoch 076 | Loss 4.06 | Val AUC 0.9863
# Epoch 077 | Loss 4.00 | Val AUC 0.9857
# Epoch 078 | Loss 4.03 | Val AUC 0.9850
# Epoch 079 | Loss 3.94 | Val AUC 0.9851
# Epoch 080 | Loss 3.91 | Val AUC 0.9853
# WD=2.782559e-06 | AUC=0.9853 | TopK=0.7722
#
# === Training with weight_decay=7.742637e-06 ===
# Epoch 001 | Loss 13.58 | Val AUC 0.9617
# Epoch 002 | Loss 8.24 | Val AUC 0.9673
# Epoch 003 | Loss 7.35 | Val AUC 0.9709
# Epoch 004 | Loss 6.89 | Val AUC 0.9736
# Epoch 005 | Loss 6.52 | Val AUC 0.9755
# Epoch 006 | Loss 6.31 | Val AUC 0.9770
# Epoch 007 | Loss 6.18 | Val AUC 0.9792
# Epoch 008 | Loss 5.96 | Val AUC 0.9809
# Epoch 009 | Loss 5.86 | Val AUC 0.9807
# Epoch 010 | Loss 5.65 | Val AUC 0.9814
# Epoch 011 | Loss 5.67 | Val AUC 0.9821
# Epoch 012 | Loss 5.45 | Val AUC 0.9825
# Epoch 013 | Loss 5.45 | Val AUC 0.9830
# Epoch 014 | Loss 5.37 | Val AUC 0.9831
# Epoch 015 | Loss 5.38 | Val AUC 0.9834
# Epoch 016 | Loss 5.20 | Val AUC 0.9835
# Epoch 017 | Loss 5.14 | Val AUC 0.9839
# Epoch 018 | Loss 5.08 | Val AUC 0.9843
# Epoch 019 | Loss 5.16 | Val AUC 0.9845
# Epoch 020 | Loss 4.89 | Val AUC 0.9847
# Epoch 021 | Loss 4.94 | Val AUC 0.9844
# Epoch 022 | Loss 4.92 | Val AUC 0.9846
# Epoch 023 | Loss 4.73 | Val AUC 0.9854
# Epoch 024 | Loss 4.81 | Val AUC 0.9851
# Epoch 025 | Loss 4.76 | Val AUC 0.9846
# Epoch 026 | Loss 4.72 | Val AUC 0.9857
# Epoch 027 | Loss 4.78 | Val AUC 0.9857
# Epoch 028 | Loss 4.76 | Val AUC 0.9855
# Epoch 029 | Loss 4.69 | Val AUC 0.9854
# Epoch 030 | Loss 4.73 | Val AUC 0.9855
# Epoch 031 | Loss 4.69 | Val AUC 0.9856
# Epoch 032 | Loss 4.59 | Val AUC 0.9862
# Epoch 033 | Loss 4.51 | Val AUC 0.9860
# Epoch 034 | Loss 4.55 | Val AUC 0.9859
# Epoch 035 | Loss 4.57 | Val AUC 0.9857
# Epoch 036 | Loss 4.46 | Val AUC 0.9859
# Epoch 037 | Loss 4.53 | Val AUC 0.9864
# Epoch 038 | Loss 4.56 | Val AUC 0.9863
# Epoch 039 | Loss 4.45 | Val AUC 0.9861
# Epoch 040 | Loss 4.38 | Val AUC 0.9861
# Epoch 041 | Loss 4.47 | Val AUC 0.9856
# Epoch 042 | Loss 4.44 | Val AUC 0.9857
# Epoch 043 | Loss 4.35 | Val AUC 0.9860
# Epoch 044 | Loss 4.38 | Val AUC 0.9861
# Epoch 045 | Loss 4.29 | Val AUC 0.9864
# Epoch 046 | Loss 4.29 | Val AUC 0.9857
# Epoch 047 | Loss 4.18 | Val AUC 0.9858
# Epoch 048 | Loss 4.31 | Val AUC 0.9860
# Epoch 049 | Loss 4.10 | Val AUC 0.9855
# Epoch 050 | Loss 4.29 | Val AUC 0.9862
# Epoch 051 | Loss 4.21 | Val AUC 0.9860
# Epoch 052 | Loss 4.24 | Val AUC 0.9867
# Epoch 053 | Loss 4.25 | Val AUC 0.9863
# Epoch 054 | Loss 4.28 | Val AUC 0.9859
# Epoch 055 | Loss 4.09 | Val AUC 0.9854
# Epoch 056 | Loss 4.12 | Val AUC 0.9856
# Epoch 057 | Loss 4.23 | Val AUC 0.9860
# Epoch 058 | Loss 4.13 | Val AUC 0.9861
# Epoch 059 | Loss 4.20 | Val AUC 0.9857
# Epoch 060 | Loss 4.13 | Val AUC 0.9856
# Epoch 061 | Loss 4.12 | Val AUC 0.9855
# Epoch 062 | Loss 4.21 | Val AUC 0.9854
# Epoch 063 | Loss 4.15 | Val AUC 0.9857
# Epoch 064 | Loss 4.11 | Val AUC 0.9860
# Epoch 065 | Loss 3.98 | Val AUC 0.9858
# Epoch 066 | Loss 3.99 | Val AUC 0.9854
# Epoch 067 | Loss 4.03 | Val AUC 0.9851
# Epoch 068 | Loss 3.95 | Val AUC 0.9854
# Epoch 069 | Loss 3.97 | Val AUC 0.9852
# Epoch 070 | Loss 4.12 | Val AUC 0.9855
# Epoch 071 | Loss 4.03 | Val AUC 0.9852
# Epoch 072 | Loss 3.99 | Val AUC 0.9852
# Epoch 073 | Loss 3.98 | Val AUC 0.9845
# Epoch 074 | Loss 3.99 | Val AUC 0.9854
# Epoch 075 | Loss 3.98 | Val AUC 0.9856
# Epoch 076 | Loss 4.03 | Val AUC 0.9862
# Epoch 077 | Loss 3.92 | Val AUC 0.9863
# Epoch 078 | Loss 3.89 | Val AUC 0.9860
# Epoch 079 | Loss 3.81 | Val AUC 0.9856
# Epoch 080 | Loss 3.90 | Val AUC 0.9860
# WD=7.742637e-06 | AUC=0.9860 | TopK=0.7595
#
# === Training with weight_decay=2.154435e-05 ===
# Epoch 001 | Loss 17.88 | Val AUC 0.9212
# Epoch 002 | Loss 9.86 | Val AUC 0.9481
# Epoch 003 | Loss 8.58 | Val AUC 0.9566
# Epoch 004 | Loss 7.82 | Val AUC 0.9631
# Epoch 005 | Loss 7.31 | Val AUC 0.9682
# Epoch 006 | Loss 6.99 | Val AUC 0.9714
# Epoch 007 | Loss 6.72 | Val AUC 0.9730
# Epoch 008 | Loss 6.43 | Val AUC 0.9746
# Epoch 009 | Loss 6.25 | Val AUC 0.9762
# Epoch 010 | Loss 6.20 | Val AUC 0.9764
# Epoch 011 | Loss 5.99 | Val AUC 0.9775
# Epoch 012 | Loss 5.93 | Val AUC 0.9783
# Epoch 013 | Loss 5.82 | Val AUC 0.9781
# Epoch 014 | Loss 5.75 | Val AUC 0.9785
# Epoch 015 | Loss 5.69 | Val AUC 0.9789
# Epoch 016 | Loss 5.61 | Val AUC 0.9788
# Epoch 017 | Loss 5.36 | Val AUC 0.9800
# Epoch 018 | Loss 5.38 | Val AUC 0.9804
# Epoch 019 | Loss 5.27 | Val AUC 0.9805
# Epoch 020 | Loss 5.25 | Val AUC 0.9808
# Epoch 021 | Loss 5.33 | Val AUC 0.9813
# Epoch 022 | Loss 5.12 | Val AUC 0.9820
# Epoch 023 | Loss 5.18 | Val AUC 0.9811
# Epoch 024 | Loss 5.13 | Val AUC 0.9817
# Epoch 025 | Loss 5.15 | Val AUC 0.9822
# Epoch 026 | Loss 5.11 | Val AUC 0.9821
# Epoch 027 | Loss 5.01 | Val AUC 0.9821
# Epoch 028 | Loss 4.90 | Val AUC 0.9824
# Epoch 029 | Loss 4.82 | Val AUC 0.9821
# Epoch 030 | Loss 4.83 | Val AUC 0.9824
# Epoch 031 | Loss 4.87 | Val AUC 0.9827
# Epoch 032 | Loss 4.89 | Val AUC 0.9831
# Epoch 033 | Loss 4.83 | Val AUC 0.9831
# Epoch 034 | Loss 4.89 | Val AUC 0.9829
# Epoch 035 | Loss 4.77 | Val AUC 0.9831
# Epoch 036 | Loss 4.70 | Val AUC 0.9829
# Epoch 037 | Loss 4.66 | Val AUC 0.9833
# Epoch 038 | Loss 4.68 | Val AUC 0.9831
# Epoch 039 | Loss 4.80 | Val AUC 0.9832
# Epoch 040 | Loss 4.67 | Val AUC 0.9832
# Epoch 041 | Loss 4.77 | Val AUC 0.9830
# Epoch 042 | Loss 4.53 | Val AUC 0.9831
# Epoch 043 | Loss 4.57 | Val AUC 0.9832
# Epoch 044 | Loss 4.65 | Val AUC 0.9832
# Epoch 045 | Loss 4.70 | Val AUC 0.9835
# Epoch 046 | Loss 4.60 | Val AUC 0.9836
# Epoch 047 | Loss 4.46 | Val AUC 0.9840
# Epoch 048 | Loss 4.52 | Val AUC 0.9838
# Epoch 049 | Loss 4.58 | Val AUC 0.9837
# Epoch 050 | Loss 4.39 | Val AUC 0.9840
# Epoch 051 | Loss 4.43 | Val AUC 0.9839
# Epoch 052 | Loss 4.39 | Val AUC 0.9843
# Epoch 053 | Loss 4.39 | Val AUC 0.9840
# Epoch 054 | Loss 4.41 | Val AUC 0.9844
# Epoch 055 | Loss 4.35 | Val AUC 0.9841
# Epoch 056 | Loss 4.37 | Val AUC 0.9843
# Epoch 057 | Loss 4.29 | Val AUC 0.9839
# Epoch 058 | Loss 4.38 | Val AUC 0.9843
# Epoch 059 | Loss 4.22 | Val AUC 0.9844
# Epoch 060 | Loss 4.45 | Val AUC 0.9838
# Epoch 061 | Loss 4.22 | Val AUC 0.9848
# Epoch 062 | Loss 4.25 | Val AUC 0.9850
# Epoch 063 | Loss 4.27 | Val AUC 0.9854
# Epoch 064 | Loss 4.23 | Val AUC 0.9854
# Epoch 065 | Loss 4.28 | Val AUC 0.9853
# Epoch 066 | Loss 4.24 | Val AUC 0.9853
# Epoch 067 | Loss 4.22 | Val AUC 0.9853
# Epoch 068 | Loss 4.19 | Val AUC 0.9851
# Epoch 069 | Loss 4.20 | Val AUC 0.9852
# Epoch 070 | Loss 4.28 | Val AUC 0.9851
# Epoch 071 | Loss 4.19 | Val AUC 0.9846
# Epoch 072 | Loss 4.12 | Val AUC 0.9854
# Epoch 073 | Loss 4.04 | Val AUC 0.9855
# Epoch 074 | Loss 4.22 | Val AUC 0.9847
# Epoch 075 | Loss 4.16 | Val AUC 0.9844
# Epoch 076 | Loss 4.07 | Val AUC 0.9846
# Epoch 077 | Loss 4.10 | Val AUC 0.9848
# Epoch 078 | Loss 4.25 | Val AUC 0.9846
# Epoch 079 | Loss 4.09 | Val AUC 0.9841
# Epoch 080 | Loss 4.13 | Val AUC 0.9839
# WD=2.154435e-05 | AUC=0.9839 | TopK=0.7722
#
# === Training with weight_decay=5.994843e-05 ===
# Epoch 001 | Loss 15.50 | Val AUC 0.9756
# Epoch 002 | Loss 8.58 | Val AUC 0.9775
# Epoch 003 | Loss 7.33 | Val AUC 0.9797
# Epoch 004 | Loss 6.93 | Val AUC 0.9795
# Epoch 005 | Loss 6.69 | Val AUC 0.9799
# Epoch 006 | Loss 6.29 | Val AUC 0.9797
# Epoch 007 | Loss 6.18 | Val AUC 0.9798
# Epoch 008 | Loss 5.96 | Val AUC 0.9812
# Epoch 009 | Loss 6.09 | Val AUC 0.9813
# Epoch 010 | Loss 5.82 | Val AUC 0.9809
# Epoch 011 | Loss 5.66 | Val AUC 0.9812
# Epoch 012 | Loss 5.54 | Val AUC 0.9822
# Epoch 013 | Loss 5.45 | Val AUC 0.9817
# Epoch 014 | Loss 5.55 | Val AUC 0.9816
# Epoch 015 | Loss 5.34 | Val AUC 0.9820
# Epoch 016 | Loss 5.31 | Val AUC 0.9822
# Epoch 017 | Loss 5.26 | Val AUC 0.9825
# Epoch 018 | Loss 5.15 | Val AUC 0.9821
# Epoch 019 | Loss 5.11 | Val AUC 0.9820
# Epoch 020 | Loss 5.03 | Val AUC 0.9818
# Epoch 021 | Loss 4.93 | Val AUC 0.9816
# Epoch 022 | Loss 4.94 | Val AUC 0.9819
# Epoch 023 | Loss 5.01 | Val AUC 0.9821
# Epoch 024 | Loss 4.84 | Val AUC 0.9822
# Epoch 025 | Loss 4.85 | Val AUC 0.9824
# Epoch 026 | Loss 4.86 | Val AUC 0.9824
# Epoch 027 | Loss 4.75 | Val AUC 0.9824
# Epoch 028 | Loss 4.75 | Val AUC 0.9828
# Epoch 029 | Loss 4.77 | Val AUC 0.9824
# Epoch 030 | Loss 4.73 | Val AUC 0.9825
# Epoch 031 | Loss 4.70 | Val AUC 0.9822
# Epoch 032 | Loss 4.77 | Val AUC 0.9827
# Epoch 033 | Loss 4.74 | Val AUC 0.9825
# Epoch 034 | Loss 4.74 | Val AUC 0.9826
# Epoch 035 | Loss 4.60 | Val AUC 0.9830
# Epoch 036 | Loss 4.63 | Val AUC 0.9829
# Epoch 037 | Loss 4.53 | Val AUC 0.9833
# Epoch 038 | Loss 4.59 | Val AUC 0.9830
# Epoch 039 | Loss 4.65 | Val AUC 0.9833
# Epoch 040 | Loss 4.55 | Val AUC 0.9833
# Epoch 041 | Loss 4.48 | Val AUC 0.9834
# Epoch 042 | Loss 4.43 | Val AUC 0.9837
# Epoch 043 | Loss 4.51 | Val AUC 0.9841
# Epoch 044 | Loss 4.39 | Val AUC 0.9842
# Epoch 045 | Loss 4.47 | Val AUC 0.9839
# Epoch 046 | Loss 4.49 | Val AUC 0.9839
# Epoch 047 | Loss 4.34 | Val AUC 0.9840
# Epoch 048 | Loss 4.31 | Val AUC 0.9839
# Epoch 049 | Loss 4.37 | Val AUC 0.9838
# Epoch 050 | Loss 4.35 | Val AUC 0.9837
# Epoch 051 | Loss 4.32 | Val AUC 0.9835
# Epoch 052 | Loss 4.30 | Val AUC 0.9835
# Epoch 053 | Loss 4.31 | Val AUC 0.9840
# Epoch 054 | Loss 4.19 | Val AUC 0.9836
# Epoch 055 | Loss 4.23 | Val AUC 0.9835
# Epoch 056 | Loss 4.21 | Val AUC 0.9839
# Epoch 057 | Loss 4.18 | Val AUC 0.9840
# Epoch 058 | Loss 4.20 | Val AUC 0.9836
# Epoch 059 | Loss 4.17 | Val AUC 0.9837
# Epoch 060 | Loss 4.19 | Val AUC 0.9837
# Epoch 061 | Loss 4.07 | Val AUC 0.9836
# Epoch 062 | Loss 4.17 | Val AUC 0.9838
# Epoch 063 | Loss 4.21 | Val AUC 0.9836
# Epoch 064 | Loss 4.11 | Val AUC 0.9837
# Epoch 065 | Loss 4.11 | Val AUC 0.9841
# Epoch 066 | Loss 4.00 | Val AUC 0.9837
# Epoch 067 | Loss 4.10 | Val AUC 0.9838
# Epoch 068 | Loss 4.18 | Val AUC 0.9841
# Epoch 069 | Loss 4.11 | Val AUC 0.9838
# Epoch 070 | Loss 4.02 | Val AUC 0.9838
# Epoch 071 | Loss 3.96 | Val AUC 0.9838
# Epoch 072 | Loss 4.09 | Val AUC 0.9835
# Epoch 073 | Loss 4.00 | Val AUC 0.9840
# Epoch 074 | Loss 4.01 | Val AUC 0.9840
# Epoch 075 | Loss 3.94 | Val AUC 0.9842
# Epoch 076 | Loss 3.99 | Val AUC 0.9839
# Epoch 077 | Loss 3.93 | Val AUC 0.9838
# Epoch 078 | Loss 3.90 | Val AUC 0.9838
# Epoch 079 | Loss 3.93 | Val AUC 0.9837
# Epoch 080 | Loss 3.92 | Val AUC 0.9838
# WD=5.994843e-05 | AUC=0.9838 | TopK=0.7658
#
# === Training with weight_decay=1.668101e-04 ===
# Epoch 001 | Loss 12.90 | Val AUC 0.9536
# Epoch 002 | Loss 8.50 | Val AUC 0.9663
# Epoch 003 | Loss 7.70 | Val AUC 0.9733
# Epoch 004 | Loss 7.27 | Val AUC 0.9755
# Epoch 005 | Loss 6.73 | Val AUC 0.9760
# Epoch 006 | Loss 6.36 | Val AUC 0.9774
# Epoch 007 | Loss 6.19 | Val AUC 0.9783
# Epoch 008 | Loss 6.07 | Val AUC 0.9787
# Epoch 009 | Loss 5.91 | Val AUC 0.9794
# Epoch 010 | Loss 5.71 | Val AUC 0.9798
# Epoch 011 | Loss 5.55 | Val AUC 0.9800
# Epoch 012 | Loss 5.48 | Val AUC 0.9798
# Epoch 013 | Loss 5.45 | Val AUC 0.9803
# Epoch 014 | Loss 5.43 | Val AUC 0.9806
# Epoch 015 | Loss 5.27 | Val AUC 0.9809
# Epoch 016 | Loss 5.31 | Val AUC 0.9807
# Epoch 017 | Loss 5.25 | Val AUC 0.9809
# Epoch 018 | Loss 5.07 | Val AUC 0.9810
# Epoch 019 | Loss 5.08 | Val AUC 0.9813
# Epoch 020 | Loss 4.93 | Val AUC 0.9816
# Epoch 021 | Loss 4.95 | Val AUC 0.9817
# Epoch 022 | Loss 5.03 | Val AUC 0.9813
# Epoch 023 | Loss 4.96 | Val AUC 0.9818
# Epoch 024 | Loss 4.75 | Val AUC 0.9817
# Epoch 025 | Loss 4.78 | Val AUC 0.9819
# Epoch 026 | Loss 4.75 | Val AUC 0.9823
# Epoch 027 | Loss 4.80 | Val AUC 0.9821
# Epoch 028 | Loss 4.80 | Val AUC 0.9822
# Epoch 029 | Loss 4.84 | Val AUC 0.9826
# Epoch 030 | Loss 4.70 | Val AUC 0.9826
# Epoch 031 | Loss 4.76 | Val AUC 0.9824
# Epoch 032 | Loss 4.61 | Val AUC 0.9824
# Epoch 033 | Loss 4.71 | Val AUC 0.9823
# Epoch 034 | Loss 4.45 | Val AUC 0.9829
# Epoch 035 | Loss 4.60 | Val AUC 0.9829
# Epoch 036 | Loss 4.55 | Val AUC 0.9828
# Epoch 037 | Loss 4.46 | Val AUC 0.9833
# Epoch 038 | Loss 4.47 | Val AUC 0.9830
# Epoch 039 | Loss 4.57 | Val AUC 0.9830
# Epoch 040 | Loss 4.43 | Val AUC 0.9835
# Epoch 041 | Loss 4.55 | Val AUC 0.9832
# Epoch 042 | Loss 4.45 | Val AUC 0.9833
# Epoch 043 | Loss 4.35 | Val AUC 0.9833
# Epoch 044 | Loss 4.37 | Val AUC 0.9838
# Epoch 045 | Loss 4.54 | Val AUC 0.9838
# Epoch 046 | Loss 4.26 | Val AUC 0.9843
# Epoch 047 | Loss 4.35 | Val AUC 0.9843
# Epoch 048 | Loss 4.26 | Val AUC 0.9847
# Epoch 049 | Loss 4.32 | Val AUC 0.9845
# Epoch 050 | Loss 4.22 | Val AUC 0.9844
# Epoch 051 | Loss 4.34 | Val AUC 0.9845
# Epoch 052 | Loss 4.23 | Val AUC 0.9843
# Epoch 053 | Loss 4.15 | Val AUC 0.9845
# Epoch 054 | Loss 4.35 | Val AUC 0.9844
# Epoch 055 | Loss 4.21 | Val AUC 0.9845
# Epoch 056 | Loss 4.22 | Val AUC 0.9839
# Epoch 057 | Loss 4.17 | Val AUC 0.9841
# Epoch 058 | Loss 4.15 | Val AUC 0.9840
# Epoch 059 | Loss 4.24 | Val AUC 0.9838
# Epoch 060 | Loss 4.21 | Val AUC 0.9843
# Epoch 061 | Loss 4.09 | Val AUC 0.9849
# Epoch 062 | Loss 4.08 | Val AUC 0.9847
# Epoch 063 | Loss 4.21 | Val AUC 0.9847
# Epoch 064 | Loss 4.12 | Val AUC 0.9849
# Epoch 065 | Loss 4.22 | Val AUC 0.9847
# Epoch 066 | Loss 4.11 | Val AUC 0.9848
# Epoch 067 | Loss 4.07 | Val AUC 0.9851
# Epoch 068 | Loss 4.01 | Val AUC 0.9849
# Epoch 069 | Loss 3.95 | Val AUC 0.9853
# Epoch 070 | Loss 4.06 | Val AUC 0.9845
# Epoch 071 | Loss 3.94 | Val AUC 0.9850
# Epoch 072 | Loss 4.03 | Val AUC 0.9844
# Epoch 073 | Loss 3.99 | Val AUC 0.9847
# Epoch 074 | Loss 3.93 | Val AUC 0.9853
# Epoch 075 | Loss 3.91 | Val AUC 0.9852
# Epoch 076 | Loss 3.88 | Val AUC 0.9851
# Epoch 077 | Loss 3.97 | Val AUC 0.9846
# Epoch 078 | Loss 3.97 | Val AUC 0.9846
# Epoch 079 | Loss 3.98 | Val AUC 0.9849
# Epoch 080 | Loss 3.90 | Val AUC 0.9850
# WD=1.668101e-04 | AUC=0.9850 | TopK=0.7658
#
# === Training with weight_decay=4.641589e-04 ===
# Epoch 001 | Loss 20.08 | Val AUC 0.9496
# Epoch 002 | Loss 8.40 | Val AUC 0.9634
# Epoch 003 | Loss 7.66 | Val AUC 0.9666
# Epoch 004 | Loss 7.08 | Val AUC 0.9715
# Epoch 005 | Loss 6.67 | Val AUC 0.9751
# Epoch 006 | Loss 6.51 | Val AUC 0.9771
# Epoch 007 | Loss 6.28 | Val AUC 0.9781
# Epoch 008 | Loss 6.10 | Val AUC 0.9793
# Epoch 009 | Loss 5.91 | Val AUC 0.9798
# Epoch 010 | Loss 5.77 | Val AUC 0.9799
# Epoch 011 | Loss 5.71 | Val AUC 0.9806
# Epoch 012 | Loss 5.77 | Val AUC 0.9807
# Epoch 013 | Loss 5.52 | Val AUC 0.9817
# Epoch 014 | Loss 5.48 | Val AUC 0.9820
# Epoch 015 | Loss 5.41 | Val AUC 0.9823
# Epoch 016 | Loss 5.30 | Val AUC 0.9829
# Epoch 017 | Loss 5.27 | Val AUC 0.9831
# Epoch 018 | Loss 5.18 | Val AUC 0.9832
# Epoch 019 | Loss 5.09 | Val AUC 0.9829
# Epoch 020 | Loss 5.11 | Val AUC 0.9833
# Epoch 021 | Loss 5.01 | Val AUC 0.9845
# Epoch 022 | Loss 5.13 | Val AUC 0.9843
# Epoch 023 | Loss 4.90 | Val AUC 0.9845
# Epoch 024 | Loss 4.95 | Val AUC 0.9842
# Epoch 025 | Loss 4.97 | Val AUC 0.9849
# Epoch 026 | Loss 4.85 | Val AUC 0.9852
# Epoch 027 | Loss 4.93 | Val AUC 0.9853
# Epoch 028 | Loss 4.79 | Val AUC 0.9856
# Epoch 029 | Loss 4.78 | Val AUC 0.9858
# Epoch 030 | Loss 4.83 | Val AUC 0.9854
# Epoch 031 | Loss 4.82 | Val AUC 0.9856
# Epoch 032 | Loss 4.75 | Val AUC 0.9857
# Epoch 033 | Loss 4.65 | Val AUC 0.9854
# Epoch 034 | Loss 4.80 | Val AUC 0.9854
# Epoch 035 | Loss 4.65 | Val AUC 0.9854
# Epoch 036 | Loss 4.62 | Val AUC 0.9852
# Epoch 037 | Loss 4.49 | Val AUC 0.9853
# Epoch 038 | Loss 4.52 | Val AUC 0.9850
# Epoch 039 | Loss 4.60 | Val AUC 0.9846
# Epoch 040 | Loss 4.56 | Val AUC 0.9851
# Epoch 041 | Loss 4.57 | Val AUC 0.9853
# Epoch 042 | Loss 4.45 | Val AUC 0.9859
# Epoch 043 | Loss 4.41 | Val AUC 0.9852
# Epoch 044 | Loss 4.50 | Val AUC 0.9853
# Epoch 045 | Loss 4.51 | Val AUC 0.9854
# Epoch 046 | Loss 4.39 | Val AUC 0.9855
# Epoch 047 | Loss 4.45 | Val AUC 0.9857
# Epoch 048 | Loss 4.35 | Val AUC 0.9858
# Epoch 049 | Loss 4.26 | Val AUC 0.9863
# Epoch 050 | Loss 4.41 | Val AUC 0.9865
# Epoch 051 | Loss 4.28 | Val AUC 0.9859
# Epoch 052 | Loss 4.34 | Val AUC 0.9856
# Epoch 053 | Loss 4.32 | Val AUC 0.9858
# Epoch 054 | Loss 4.30 | Val AUC 0.9860
# Epoch 055 | Loss 4.37 | Val AUC 0.9865
# Epoch 056 | Loss 4.26 | Val AUC 0.9866
# Epoch 057 | Loss 4.25 | Val AUC 0.9862
# Epoch 058 | Loss 4.23 | Val AUC 0.9858
# Epoch 059 | Loss 4.32 | Val AUC 0.9866
# Epoch 060 | Loss 4.17 | Val AUC 0.9866
# Epoch 061 | Loss 4.16 | Val AUC 0.9868
# Epoch 062 | Loss 4.16 | Val AUC 0.9862
# Epoch 063 | Loss 4.15 | Val AUC 0.9866
# Epoch 064 | Loss 4.20 | Val AUC 0.9865
# Epoch 065 | Loss 4.26 | Val AUC 0.9865
# Epoch 066 | Loss 4.13 | Val AUC 0.9862
# Epoch 067 | Loss 4.20 | Val AUC 0.9866
# Epoch 068 | Loss 4.14 | Val AUC 0.9864
# Epoch 069 | Loss 4.08 | Val AUC 0.9864
# Epoch 070 | Loss 4.09 | Val AUC 0.9867
# Epoch 071 | Loss 4.18 | Val AUC 0.9866
# Epoch 072 | Loss 4.03 | Val AUC 0.9861
# Epoch 073 | Loss 4.07 | Val AUC 0.9861
# Epoch 074 | Loss 4.07 | Val AUC 0.9869
# Epoch 075 | Loss 4.08 | Val AUC 0.9865
# Epoch 076 | Loss 4.01 | Val AUC 0.9853
# Epoch 077 | Loss 4.09 | Val AUC 0.9863
# Epoch 078 | Loss 3.92 | Val AUC 0.9856
# Epoch 079 | Loss 3.99 | Val AUC 0.9857
# Epoch 080 | Loss 3.97 | Val AUC 0.9853
# WD=4.641589e-04 | AUC=0.9853 | TopK=0.7722
#
# === Training with weight_decay=1.291550e-03 ===
# Epoch 001 | Loss 17.80 | Val AUC 0.9487
# Epoch 002 | Loss 9.41 | Val AUC 0.9645
# Epoch 003 | Loss 7.70 | Val AUC 0.9707
# Epoch 004 | Loss 7.22 | Val AUC 0.9736
# Epoch 005 | Loss 6.85 | Val AUC 0.9747
# Epoch 006 | Loss 6.62 | Val AUC 0.9759
# Epoch 007 | Loss 6.53 | Val AUC 0.9777
# Epoch 008 | Loss 6.31 | Val AUC 0.9780
# Epoch 009 | Loss 6.12 | Val AUC 0.9789
# Epoch 010 | Loss 5.93 | Val AUC 0.9801
# Epoch 011 | Loss 5.82 | Val AUC 0.9804
# Epoch 012 | Loss 5.75 | Val AUC 0.9806
# Epoch 013 | Loss 5.62 | Val AUC 0.9806
# Epoch 014 | Loss 5.55 | Val AUC 0.9810
# Epoch 015 | Loss 5.35 | Val AUC 0.9813
# Epoch 016 | Loss 5.38 | Val AUC 0.9813
# Epoch 017 | Loss 5.32 | Val AUC 0.9809
# Epoch 018 | Loss 5.38 | Val AUC 0.9810
# Epoch 019 | Loss 5.15 | Val AUC 0.9815
# Epoch 020 | Loss 5.17 | Val AUC 0.9817
# Epoch 021 | Loss 5.09 | Val AUC 0.9823
# Epoch 022 | Loss 5.07 | Val AUC 0.9815
# Epoch 023 | Loss 5.03 | Val AUC 0.9817
# Epoch 024 | Loss 5.04 | Val AUC 0.9817
# Epoch 025 | Loss 4.98 | Val AUC 0.9822
# Epoch 026 | Loss 4.96 | Val AUC 0.9822
# Epoch 027 | Loss 4.81 | Val AUC 0.9820
# Epoch 028 | Loss 4.83 | Val AUC 0.9819
# Epoch 029 | Loss 4.82 | Val AUC 0.9825
# Epoch 030 | Loss 4.78 | Val AUC 0.9827
# Epoch 031 | Loss 4.73 | Val AUC 0.9828
# Epoch 032 | Loss 4.78 | Val AUC 0.9830
# Epoch 033 | Loss 4.76 | Val AUC 0.9826
# Epoch 034 | Loss 4.66 | Val AUC 0.9828
# Epoch 035 | Loss 4.70 | Val AUC 0.9831
# Epoch 036 | Loss 4.64 | Val AUC 0.9829
# Epoch 037 | Loss 4.48 | Val AUC 0.9829
# Epoch 038 | Loss 4.59 | Val AUC 0.9825
# Epoch 039 | Loss 4.62 | Val AUC 0.9829
# Epoch 040 | Loss 4.44 | Val AUC 0.9828
# Epoch 041 | Loss 4.42 | Val AUC 0.9831
# Epoch 042 | Loss 4.40 | Val AUC 0.9827
# Epoch 043 | Loss 4.45 | Val AUC 0.9830
# Epoch 044 | Loss 4.46 | Val AUC 0.9829
# Epoch 045 | Loss 4.53 | Val AUC 0.9832
# Epoch 046 | Loss 4.38 | Val AUC 0.9834
# Epoch 047 | Loss 4.33 | Val AUC 0.9833
# Epoch 048 | Loss 4.38 | Val AUC 0.9832
# Epoch 049 | Loss 4.33 | Val AUC 0.9832
# Epoch 050 | Loss 4.39 | Val AUC 0.9836
# Epoch 051 | Loss 4.40 | Val AUC 0.9841
# Epoch 052 | Loss 4.29 | Val AUC 0.9839
# Epoch 053 | Loss 4.23 | Val AUC 0.9841
# Epoch 054 | Loss 4.23 | Val AUC 0.9843
# Epoch 055 | Loss 4.18 | Val AUC 0.9845
# Epoch 056 | Loss 4.23 | Val AUC 0.9847
# Epoch 057 | Loss 4.25 | Val AUC 0.9842
# Epoch 058 | Loss 4.21 | Val AUC 0.9844
# Epoch 059 | Loss 4.21 | Val AUC 0.9848
# Epoch 060 | Loss 4.22 | Val AUC 0.9849
# Epoch 061 | Loss 4.21 | Val AUC 0.9852
# Epoch 062 | Loss 4.10 | Val AUC 0.9851
# Epoch 063 | Loss 4.15 | Val AUC 0.9849
# Epoch 064 | Loss 4.27 | Val AUC 0.9846
# Epoch 065 | Loss 4.18 | Val AUC 0.9851
# Epoch 066 | Loss 4.18 | Val AUC 0.9851
# Epoch 067 | Loss 4.12 | Val AUC 0.9852
# Epoch 068 | Loss 4.00 | Val AUC 0.9853
# Epoch 069 | Loss 4.17 | Val AUC 0.9852
# Epoch 070 | Loss 3.98 | Val AUC 0.9859
# Epoch 071 | Loss 4.06 | Val AUC 0.9862
# Epoch 072 | Loss 3.98 | Val AUC 0.9857
# Epoch 073 | Loss 3.95 | Val AUC 0.9858
# Epoch 074 | Loss 3.99 | Val AUC 0.9856
# Epoch 075 | Loss 4.05 | Val AUC 0.9850
# Epoch 076 | Loss 3.99 | Val AUC 0.9852
# Epoch 077 | Loss 4.00 | Val AUC 0.9849
# Epoch 078 | Loss 3.99 | Val AUC 0.9849
# Epoch 079 | Loss 3.91 | Val AUC 0.9848
# Epoch 080 | Loss 4.00 | Val AUC 0.9852
# WD=1.291550e-03 | AUC=0.9852 | TopK=0.7595
#
# === Training with weight_decay=3.593814e-03 ===
# Epoch 001 | Loss 12.53 | Val AUC 0.9504
# Epoch 002 | Loss 8.35 | Val AUC 0.9659
# Epoch 003 | Loss 7.48 | Val AUC 0.9711
# Epoch 004 | Loss 6.95 | Val AUC 0.9738
# Epoch 005 | Loss 6.61 | Val AUC 0.9750
# Epoch 006 | Loss 6.34 | Val AUC 0.9769
# Epoch 007 | Loss 5.99 | Val AUC 0.9779
# Epoch 008 | Loss 5.92 | Val AUC 0.9781
# Epoch 009 | Loss 5.68 | Val AUC 0.9791
# Epoch 010 | Loss 5.52 | Val AUC 0.9795
# Epoch 011 | Loss 5.41 | Val AUC 0.9800
# Epoch 012 | Loss 5.46 | Val AUC 0.9804
# Epoch 013 | Loss 5.22 | Val AUC 0.9813
# Epoch 014 | Loss 5.06 | Val AUC 0.9815
# Epoch 015 | Loss 5.19 | Val AUC 0.9816
# Epoch 016 | Loss 5.05 | Val AUC 0.9820
# Epoch 017 | Loss 5.06 | Val AUC 0.9821
# Epoch 018 | Loss 4.95 | Val AUC 0.9826
# Epoch 019 | Loss 4.92 | Val AUC 0.9825
# Epoch 020 | Loss 4.86 | Val AUC 0.9827
# Epoch 021 | Loss 4.89 | Val AUC 0.9830
# Epoch 022 | Loss 4.86 | Val AUC 0.9831
# Epoch 023 | Loss 4.74 | Val AUC 0.9833
# Epoch 024 | Loss 4.81 | Val AUC 0.9831
# Epoch 025 | Loss 4.80 | Val AUC 0.9831
# Epoch 026 | Loss 4.64 | Val AUC 0.9835
# Epoch 027 | Loss 4.77 | Val AUC 0.9835
# Epoch 028 | Loss 4.68 | Val AUC 0.9837
# Epoch 029 | Loss 4.70 | Val AUC 0.9836
# Epoch 030 | Loss 4.58 | Val AUC 0.9838
# Epoch 031 | Loss 4.57 | Val AUC 0.9837
# Epoch 032 | Loss 4.56 | Val AUC 0.9838
# Epoch 033 | Loss 4.50 | Val AUC 0.9842
# Epoch 034 | Loss 4.55 | Val AUC 0.9843
# Epoch 035 | Loss 4.52 | Val AUC 0.9844
# Epoch 036 | Loss 4.54 | Val AUC 0.9849
# Epoch 037 | Loss 4.63 | Val AUC 0.9850
# Epoch 038 | Loss 4.43 | Val AUC 0.9851
# Epoch 039 | Loss 4.63 | Val AUC 0.9848
# Epoch 040 | Loss 4.42 | Val AUC 0.9849
# Epoch 041 | Loss 4.56 | Val AUC 0.9844
# Epoch 042 | Loss 4.39 | Val AUC 0.9847
# Epoch 043 | Loss 4.39 | Val AUC 0.9851
# Epoch 044 | Loss 4.37 | Val AUC 0.9849
# Epoch 045 | Loss 4.42 | Val AUC 0.9856
# Epoch 046 | Loss 4.33 | Val AUC 0.9852
# Epoch 047 | Loss 4.41 | Val AUC 0.9848
# Epoch 048 | Loss 4.33 | Val AUC 0.9848
# Epoch 049 | Loss 4.31 | Val AUC 0.9850
# Epoch 050 | Loss 4.31 | Val AUC 0.9852
# Epoch 051 | Loss 4.26 | Val AUC 0.9848
# Epoch 052 | Loss 4.29 | Val AUC 0.9849
# Epoch 053 | Loss 4.25 | Val AUC 0.9850
# Epoch 054 | Loss 4.16 | Val AUC 0.9850
# Epoch 055 | Loss 4.27 | Val AUC 0.9852
# Epoch 056 | Loss 4.28 | Val AUC 0.9849
# Epoch 057 | Loss 4.28 | Val AUC 0.9850
# Epoch 058 | Loss 4.26 | Val AUC 0.9850
# Epoch 059 | Loss 4.18 | Val AUC 0.9850
# Epoch 060 | Loss 4.20 | Val AUC 0.9852
# Epoch 061 | Loss 4.17 | Val AUC 0.9852
# Epoch 062 | Loss 4.23 | Val AUC 0.9852
# Epoch 063 | Loss 4.14 | Val AUC 0.9851
# Epoch 064 | Loss 4.09 | Val AUC 0.9856
# Epoch 065 | Loss 4.16 | Val AUC 0.9857
# Epoch 066 | Loss 4.12 | Val AUC 0.9854
# Epoch 067 | Loss 4.08 | Val AUC 0.9856
# Epoch 068 | Loss 4.21 | Val AUC 0.9852
# Epoch 069 | Loss 4.10 | Val AUC 0.9852
# Epoch 070 | Loss 4.14 | Val AUC 0.9851
# Epoch 071 | Loss 4.09 | Val AUC 0.9854
# Epoch 072 | Loss 4.05 | Val AUC 0.9849
# Epoch 073 | Loss 4.00 | Val AUC 0.9852
# Epoch 074 | Loss 3.98 | Val AUC 0.9855
# Epoch 075 | Loss 3.96 | Val AUC 0.9853
# Epoch 076 | Loss 4.06 | Val AUC 0.9853
# Epoch 077 | Loss 4.03 | Val AUC 0.9854
# Epoch 078 | Loss 3.88 | Val AUC 0.9851
# Epoch 079 | Loss 3.99 | Val AUC 0.9853
# Epoch 080 | Loss 3.98 | Val AUC 0.9855
# WD=3.593814e-03 | AUC=0.9855 | TopK=0.7785
#
# === Training with weight_decay=1.000000e-02 ===
# Epoch 001 | Loss 12.62 | Val AUC 0.9568
# Epoch 002 | Loss 8.44 | Val AUC 0.9675
# Epoch 003 | Loss 7.55 | Val AUC 0.9718
# Epoch 004 | Loss 7.14 | Val AUC 0.9756
# Epoch 005 | Loss 6.74 | Val AUC 0.9782
# Epoch 006 | Loss 6.55 | Val AUC 0.9794
# Epoch 007 | Loss 6.36 | Val AUC 0.9800
# Epoch 008 | Loss 6.14 | Val AUC 0.9811
# Epoch 009 | Loss 5.99 | Val AUC 0.9812
# Epoch 010 | Loss 5.82 | Val AUC 0.9818
# Epoch 011 | Loss 5.67 | Val AUC 0.9822
# Epoch 012 | Loss 5.54 | Val AUC 0.9823
# Epoch 013 | Loss 5.54 | Val AUC 0.9827
# Epoch 014 | Loss 5.44 | Val AUC 0.9818
# Epoch 015 | Loss 5.27 | Val AUC 0.9825
# Epoch 016 | Loss 5.36 | Val AUC 0.9828
# Epoch 017 | Loss 5.20 | Val AUC 0.9816
# Epoch 018 | Loss 5.17 | Val AUC 0.9826
# Epoch 019 | Loss 5.10 | Val AUC 0.9820
# Epoch 020 | Loss 5.06 | Val AUC 0.9828
# Epoch 021 | Loss 4.98 | Val AUC 0.9828
# Epoch 022 | Loss 4.95 | Val AUC 0.9822
# Epoch 023 | Loss 4.88 | Val AUC 0.9822
# Epoch 024 | Loss 4.89 | Val AUC 0.9827
# Epoch 025 | Loss 4.90 | Val AUC 0.9826
# Epoch 026 | Loss 4.76 | Val AUC 0.9825
# Epoch 027 | Loss 4.81 | Val AUC 0.9826
# Epoch 028 | Loss 4.68 | Val AUC 0.9828
# Epoch 029 | Loss 4.65 | Val AUC 0.9829
# Epoch 030 | Loss 4.72 | Val AUC 0.9829
# Epoch 031 | Loss 4.70 | Val AUC 0.9824
# Epoch 032 | Loss 4.62 | Val AUC 0.9820
# Epoch 033 | Loss 4.64 | Val AUC 0.9824
# Epoch 034 | Loss 4.66 | Val AUC 0.9824
# Epoch 035 | Loss 4.58 | Val AUC 0.9828
# Epoch 036 | Loss 4.54 | Val AUC 0.9826
# Epoch 037 | Loss 4.52 | Val AUC 0.9825
# Epoch 038 | Loss 4.53 | Val AUC 0.9823
# Epoch 039 | Loss 4.56 | Val AUC 0.9820
# Epoch 040 | Loss 4.48 | Val AUC 0.9819
# Epoch 041 | Loss 4.52 | Val AUC 0.9825
# Epoch 042 | Loss 4.42 | Val AUC 0.9820
# Epoch 043 | Loss 4.42 | Val AUC 0.9812
# Epoch 044 | Loss 4.43 | Val AUC 0.9814
# Epoch 045 | Loss 4.39 | Val AUC 0.9814
# Epoch 046 | Loss 4.46 | Val AUC 0.9814
# Epoch 047 | Loss 4.31 | Val AUC 0.9815
# Epoch 048 | Loss 4.37 | Val AUC 0.9811
# Epoch 049 | Loss 4.30 | Val AUC 0.9807
# Epoch 050 | Loss 4.28 | Val AUC 0.9805
# Epoch 051 | Loss 4.34 | Val AUC 0.9804
# Epoch 052 | Loss 4.27 | Val AUC 0.9808
# Epoch 053 | Loss 4.34 | Val AUC 0.9809
# Epoch 054 | Loss 4.36 | Val AUC 0.9800
# Epoch 055 | Loss 4.19 | Val AUC 0.9798
# Epoch 056 | Loss 4.15 | Val AUC 0.9802
# Epoch 057 | Loss 4.21 | Val AUC 0.9798
# Epoch 058 | Loss 4.12 | Val AUC 0.9797
# Epoch 059 | Loss 4.26 | Val AUC 0.9799
# Epoch 060 | Loss 4.20 | Val AUC 0.9801
# Epoch 061 | Loss 4.06 | Val AUC 0.9794
# Epoch 062 | Loss 4.16 | Val AUC 0.9796
# Epoch 063 | Loss 4.14 | Val AUC 0.9795
# Epoch 064 | Loss 4.13 | Val AUC 0.9796
# Epoch 065 | Loss 4.11 | Val AUC 0.9795
# Epoch 066 | Loss 4.02 | Val AUC 0.9792
# Epoch 067 | Loss 4.09 | Val AUC 0.9790
# Epoch 068 | Loss 4.08 | Val AUC 0.9800
# Epoch 069 | Loss 4.12 | Val AUC 0.9792
# Epoch 070 | Loss 4.01 | Val AUC 0.9786
# Epoch 071 | Loss 4.03 | Val AUC 0.9792
# Epoch 072 | Loss 4.03 | Val AUC 0.9796
# Epoch 073 | Loss 3.98 | Val AUC 0.9803
# Epoch 074 | Loss 4.05 | Val AUC 0.9803
# Epoch 075 | Loss 3.96 | Val AUC 0.9799
# Epoch 076 | Loss 4.11 | Val AUC 0.9806
# Epoch 077 | Loss 3.95 | Val AUC 0.9805
# Epoch 078 | Loss 4.07 | Val AUC 0.9805
# Epoch 079 | Loss 3.89 | Val AUC 0.9810
# Epoch 080 | Loss 4.01 | Val AUC 0.9795
# WD=1.000000e-02 | AUC=0.9795 | TopK=0.7658
#
# Best weight decay: 0.003593813663804626
# Best Validation TopK: 0.7785
#
# RAW RESULT:
# Best WD: 0.003593813663804626
# Val AUC: 0.9855
# Val TopK: 0.7785
#
#
# ==============================
# RUNNING NN ON ENGINEERED DATA
# ==============================
#
# === Training with weight_decay=1.000000e-06 ===
# Epoch 001 | Loss 19.67 | Val AUC 0.9529
# Epoch 002 | Loss 11.79 | Val AUC 0.9684
# Epoch 003 | Loss 9.47 | Val AUC 0.9748
# Epoch 004 | Loss 8.80 | Val AUC 0.9778
# Epoch 005 | Loss 8.24 | Val AUC 0.9805
# Epoch 006 | Loss 7.94 | Val AUC 0.9819
# Epoch 007 | Loss 7.59 | Val AUC 0.9825
# Epoch 008 | Loss 7.58 | Val AUC 0.9835
# Epoch 009 | Loss 7.38 | Val AUC 0.9843
# Epoch 010 | Loss 7.24 | Val AUC 0.9844
# Epoch 011 | Loss 6.85 | Val AUC 0.9848
# Epoch 012 | Loss 6.68 | Val AUC 0.9851
# Epoch 013 | Loss 6.64 | Val AUC 0.9854
# Epoch 014 | Loss 6.62 | Val AUC 0.9855
# Epoch 015 | Loss 6.30 | Val AUC 0.9858
# Epoch 016 | Loss 6.35 | Val AUC 0.9860
# Epoch 017 | Loss 6.16 | Val AUC 0.9863
# Epoch 018 | Loss 6.14 | Val AUC 0.9867
# Epoch 019 | Loss 5.95 | Val AUC 0.9865
# Epoch 020 | Loss 6.20 | Val AUC 0.9862
# Epoch 021 | Loss 5.96 | Val AUC 0.9864
# Epoch 022 | Loss 5.82 | Val AUC 0.9866
# Epoch 023 | Loss 5.78 | Val AUC 0.9861
# Epoch 024 | Loss 5.74 | Val AUC 0.9863
# Epoch 025 | Loss 5.66 | Val AUC 0.9864
# Epoch 026 | Loss 5.72 | Val AUC 0.9859
# Epoch 027 | Loss 5.65 | Val AUC 0.9861
# Epoch 028 | Loss 5.71 | Val AUC 0.9860
# Epoch 029 | Loss 5.62 | Val AUC 0.9860
# Epoch 030 | Loss 5.50 | Val AUC 0.9861
# Epoch 031 | Loss 5.39 | Val AUC 0.9861
# Epoch 032 | Loss 5.43 | Val AUC 0.9860
# Epoch 033 | Loss 5.46 | Val AUC 0.9860
# Epoch 034 | Loss 5.57 | Val AUC 0.9860
# Epoch 035 | Loss 5.43 | Val AUC 0.9857
# Epoch 036 | Loss 5.49 | Val AUC 0.9857
# Epoch 037 | Loss 5.35 | Val AUC 0.9851
# Epoch 038 | Loss 5.28 | Val AUC 0.9847
# Epoch 039 | Loss 5.21 | Val AUC 0.9854
# Epoch 040 | Loss 5.33 | Val AUC 0.9850
# Epoch 041 | Loss 5.24 | Val AUC 0.9852
# Epoch 042 | Loss 5.23 | Val AUC 0.9850
# Epoch 043 | Loss 5.15 | Val AUC 0.9849
# Epoch 044 | Loss 5.18 | Val AUC 0.9853
# Epoch 045 | Loss 5.14 | Val AUC 0.9850
# Epoch 046 | Loss 5.14 | Val AUC 0.9850
# Epoch 047 | Loss 4.99 | Val AUC 0.9853
# Epoch 048 | Loss 5.04 | Val AUC 0.9851
# Epoch 049 | Loss 5.15 | Val AUC 0.9856
# Epoch 050 | Loss 4.94 | Val AUC 0.9856
# Epoch 051 | Loss 5.04 | Val AUC 0.9862
# Epoch 052 | Loss 4.97 | Val AUC 0.9857
# Epoch 053 | Loss 5.02 | Val AUC 0.9858
# Epoch 054 | Loss 4.96 | Val AUC 0.9857
# Epoch 055 | Loss 5.00 | Val AUC 0.9860
# Epoch 056 | Loss 4.88 | Val AUC 0.9859
# Epoch 057 | Loss 4.94 | Val AUC 0.9863
# Epoch 058 | Loss 4.85 | Val AUC 0.9864
# Epoch 059 | Loss 4.92 | Val AUC 0.9867
# Epoch 060 | Loss 4.91 | Val AUC 0.9869
# Epoch 061 | Loss 4.87 | Val AUC 0.9866
# Epoch 062 | Loss 4.79 | Val AUC 0.9867
# Epoch 063 | Loss 4.86 | Val AUC 0.9867
# Epoch 064 | Loss 4.79 | Val AUC 0.9869
# Epoch 065 | Loss 4.88 | Val AUC 0.9871
# Epoch 066 | Loss 4.68 | Val AUC 0.9871
# Epoch 067 | Loss 4.69 | Val AUC 0.9866
# Epoch 068 | Loss 4.79 | Val AUC 0.9870
# Epoch 069 | Loss 4.68 | Val AUC 0.9870
# Epoch 070 | Loss 4.72 | Val AUC 0.9872
# Epoch 071 | Loss 4.69 | Val AUC 0.9872
# Epoch 072 | Loss 4.73 | Val AUC 0.9871
# Epoch 073 | Loss 4.60 | Val AUC 0.9867
# Epoch 074 | Loss 4.62 | Val AUC 0.9870
# Epoch 075 | Loss 4.58 | Val AUC 0.9867
# Epoch 076 | Loss 4.52 | Val AUC 0.9873
# Epoch 077 | Loss 4.56 | Val AUC 0.9874
# Epoch 078 | Loss 4.60 | Val AUC 0.9876
# Epoch 079 | Loss 4.49 | Val AUC 0.9878
# Epoch 080 | Loss 4.61 | Val AUC 0.9875
# WD=1.000000e-06 | AUC=0.9875 | TopK=0.7785
#
# === Training with weight_decay=2.782559e-06 ===
# Epoch 001 | Loss 18.22 | Val AUC 0.9793
# Epoch 002 | Loss 10.70 | Val AUC 0.9805
# Epoch 003 | Loss 9.21 | Val AUC 0.9806
# Epoch 004 | Loss 8.38 | Val AUC 0.9812
# Epoch 005 | Loss 8.06 | Val AUC 0.9818
# Epoch 006 | Loss 7.82 | Val AUC 0.9825
# Epoch 007 | Loss 7.78 | Val AUC 0.9826
# Epoch 008 | Loss 7.49 | Val AUC 0.9826
# Epoch 009 | Loss 7.08 | Val AUC 0.9832
# Epoch 010 | Loss 7.06 | Val AUC 0.9837
# Epoch 011 | Loss 6.82 | Val AUC 0.9838
# Epoch 012 | Loss 6.74 | Val AUC 0.9836
# Epoch 013 | Loss 6.50 | Val AUC 0.9835
# Epoch 014 | Loss 6.48 | Val AUC 0.9836
# Epoch 015 | Loss 6.61 | Val AUC 0.9839
# Epoch 016 | Loss 6.48 | Val AUC 0.9839
# Epoch 017 | Loss 6.33 | Val AUC 0.9838
# Epoch 018 | Loss 6.30 | Val AUC 0.9843
# Epoch 019 | Loss 6.28 | Val AUC 0.9845
# Epoch 020 | Loss 6.18 | Val AUC 0.9844
# Epoch 021 | Loss 6.09 | Val AUC 0.9845
# Epoch 022 | Loss 6.09 | Val AUC 0.9844
# Epoch 023 | Loss 5.98 | Val AUC 0.9846
# Epoch 024 | Loss 5.96 | Val AUC 0.9845
# Epoch 025 | Loss 5.95 | Val AUC 0.9846
# Epoch 026 | Loss 5.86 | Val AUC 0.9846
# Epoch 027 | Loss 5.82 | Val AUC 0.9844
# Epoch 028 | Loss 5.70 | Val AUC 0.9844
# Epoch 029 | Loss 5.73 | Val AUC 0.9845
# Epoch 030 | Loss 5.84 | Val AUC 0.9841
# Epoch 031 | Loss 5.78 | Val AUC 0.9842
# Epoch 032 | Loss 5.75 | Val AUC 0.9843
# Epoch 033 | Loss 5.60 | Val AUC 0.9844
# Epoch 034 | Loss 5.74 | Val AUC 0.9845
# Epoch 035 | Loss 5.50 | Val AUC 0.9841
# Epoch 036 | Loss 5.61 | Val AUC 0.9845
# Epoch 037 | Loss 5.50 | Val AUC 0.9844
# Epoch 038 | Loss 5.62 | Val AUC 0.9847
# Epoch 039 | Loss 5.54 | Val AUC 0.9848
# Epoch 040 | Loss 5.52 | Val AUC 0.9848
# Epoch 041 | Loss 5.51 | Val AUC 0.9850
# Epoch 042 | Loss 5.51 | Val AUC 0.9855
# Epoch 043 | Loss 5.35 | Val AUC 0.9856
# Epoch 044 | Loss 5.38 | Val AUC 0.9853
# Epoch 045 | Loss 5.36 | Val AUC 0.9850
# Epoch 046 | Loss 5.29 | Val AUC 0.9853
# Epoch 047 | Loss 5.34 | Val AUC 0.9850
# Epoch 048 | Loss 5.45 | Val AUC 0.9850
# Epoch 049 | Loss 5.24 | Val AUC 0.9850
# Epoch 050 | Loss 5.21 | Val AUC 0.9849
# Epoch 051 | Loss 5.09 | Val AUC 0.9850
# Epoch 052 | Loss 5.15 | Val AUC 0.9851
# Epoch 053 | Loss 5.15 | Val AUC 0.9851
# Epoch 054 | Loss 5.12 | Val AUC 0.9850
# Epoch 055 | Loss 5.10 | Val AUC 0.9852
# Epoch 056 | Loss 5.19 | Val AUC 0.9855
# Epoch 057 | Loss 5.16 | Val AUC 0.9855
# Epoch 058 | Loss 5.08 | Val AUC 0.9853
# Epoch 059 | Loss 5.03 | Val AUC 0.9849
# Epoch 060 | Loss 5.07 | Val AUC 0.9848
# Epoch 061 | Loss 4.94 | Val AUC 0.9849
# Epoch 062 | Loss 5.12 | Val AUC 0.9852
# Epoch 063 | Loss 5.04 | Val AUC 0.9869
# Epoch 064 | Loss 4.92 | Val AUC 0.9866
# Epoch 065 | Loss 4.97 | Val AUC 0.9859
# Epoch 066 | Loss 5.00 | Val AUC 0.9854
# Epoch 067 | Loss 4.90 | Val AUC 0.9849
# Epoch 068 | Loss 4.91 | Val AUC 0.9851
# Epoch 069 | Loss 4.87 | Val AUC 0.9867
# Epoch 070 | Loss 4.94 | Val AUC 0.9859
# Epoch 071 | Loss 4.87 | Val AUC 0.9877
# Epoch 072 | Loss 4.94 | Val AUC 0.9876
# Epoch 073 | Loss 4.86 | Val AUC 0.9883
# Epoch 074 | Loss 4.83 | Val AUC 0.9880
# Epoch 075 | Loss 4.89 | Val AUC 0.9879
# Epoch 076 | Loss 4.79 | Val AUC 0.9883
# Epoch 077 | Loss 4.82 | Val AUC 0.9880
# Epoch 078 | Loss 4.79 | Val AUC 0.9874
# Epoch 079 | Loss 4.66 | Val AUC 0.9878
# Epoch 080 | Loss 4.80 | Val AUC 0.9883
# WD=2.782559e-06 | AUC=0.9883 | TopK=0.7595
#
# === Training with weight_decay=7.742637e-06 ===
# Epoch 001 | Loss 26.37 | Val AUC 0.9577
# Epoch 002 | Loss 11.44 | Val AUC 0.9690
# Epoch 003 | Loss 9.58 | Val AUC 0.9734
# Epoch 004 | Loss 8.69 | Val AUC 0.9754
# Epoch 005 | Loss 8.20 | Val AUC 0.9776
# Epoch 006 | Loss 7.98 | Val AUC 0.9789
# Epoch 007 | Loss 7.59 | Val AUC 0.9795
# Epoch 008 | Loss 7.43 | Val AUC 0.9804
# Epoch 009 | Loss 7.44 | Val AUC 0.9804
# Epoch 010 | Loss 7.13 | Val AUC 0.9808
# Epoch 011 | Loss 6.98 | Val AUC 0.9812
# Epoch 012 | Loss 6.86 | Val AUC 0.9811
# Epoch 013 | Loss 6.66 | Val AUC 0.9816
# Epoch 014 | Loss 6.71 | Val AUC 0.9822
# Epoch 015 | Loss 6.78 | Val AUC 0.9822
# Epoch 016 | Loss 6.54 | Val AUC 0.9821
# Epoch 017 | Loss 6.55 | Val AUC 0.9823
# Epoch 018 | Loss 6.38 | Val AUC 0.9825
# Epoch 019 | Loss 6.36 | Val AUC 0.9830
# Epoch 020 | Loss 6.27 | Val AUC 0.9834
# Epoch 021 | Loss 6.15 | Val AUC 0.9835
# Epoch 022 | Loss 6.22 | Val AUC 0.9840
# Epoch 023 | Loss 6.09 | Val AUC 0.9840
# Epoch 024 | Loss 5.92 | Val AUC 0.9839
# Epoch 025 | Loss 6.03 | Val AUC 0.9840
# Epoch 026 | Loss 5.87 | Val AUC 0.9844
# Epoch 027 | Loss 5.79 | Val AUC 0.9847
# Epoch 028 | Loss 5.62 | Val AUC 0.9849
# Epoch 029 | Loss 5.89 | Val AUC 0.9850
# Epoch 030 | Loss 5.70 | Val AUC 0.9850
# Epoch 031 | Loss 5.88 | Val AUC 0.9849
# Epoch 032 | Loss 5.65 | Val AUC 0.9850
# Epoch 033 | Loss 5.63 | Val AUC 0.9852
# Epoch 034 | Loss 5.69 | Val AUC 0.9853
# Epoch 035 | Loss 5.61 | Val AUC 0.9854
# Epoch 036 | Loss 5.55 | Val AUC 0.9858
# Epoch 037 | Loss 5.57 | Val AUC 0.9860
# Epoch 038 | Loss 5.52 | Val AUC 0.9862
# Epoch 039 | Loss 5.42 | Val AUC 0.9857
# Epoch 040 | Loss 5.53 | Val AUC 0.9862
# Epoch 041 | Loss 5.48 | Val AUC 0.9863
# Epoch 042 | Loss 5.36 | Val AUC 0.9863
# Epoch 043 | Loss 5.36 | Val AUC 0.9857
# Epoch 044 | Loss 5.35 | Val AUC 0.9865
# Epoch 045 | Loss 5.26 | Val AUC 0.9866
# Epoch 046 | Loss 5.29 | Val AUC 0.9866
# Epoch 047 | Loss 5.20 | Val AUC 0.9865
# Epoch 048 | Loss 5.33 | Val AUC 0.9867
# Epoch 049 | Loss 5.15 | Val AUC 0.9865
# Epoch 050 | Loss 5.18 | Val AUC 0.9864
# Epoch 051 | Loss 5.20 | Val AUC 0.9865
# Epoch 052 | Loss 5.22 | Val AUC 0.9869
# Epoch 053 | Loss 5.07 | Val AUC 0.9864
# Epoch 054 | Loss 5.04 | Val AUC 0.9866
# Epoch 055 | Loss 5.09 | Val AUC 0.9867
# Epoch 056 | Loss 5.12 | Val AUC 0.9864
# Epoch 057 | Loss 4.93 | Val AUC 0.9866
# Epoch 058 | Loss 5.06 | Val AUC 0.9869
# Epoch 059 | Loss 4.96 | Val AUC 0.9866
# Epoch 060 | Loss 4.98 | Val AUC 0.9865
# Epoch 061 | Loss 4.96 | Val AUC 0.9866
# Epoch 062 | Loss 4.99 | Val AUC 0.9866
# Epoch 063 | Loss 5.04 | Val AUC 0.9865
# Epoch 064 | Loss 4.89 | Val AUC 0.9862
# Epoch 065 | Loss 4.88 | Val AUC 0.9864
# Epoch 066 | Loss 4.99 | Val AUC 0.9867
# Epoch 067 | Loss 4.71 | Val AUC 0.9867
# Epoch 068 | Loss 4.82 | Val AUC 0.9866
# Epoch 069 | Loss 4.83 | Val AUC 0.9860
# Epoch 070 | Loss 4.79 | Val AUC 0.9857
# Epoch 071 | Loss 4.79 | Val AUC 0.9861
# Epoch 072 | Loss 4.77 | Val AUC 0.9860
# Epoch 073 | Loss 4.92 | Val AUC 0.9858
# Epoch 074 | Loss 4.72 | Val AUC 0.9857
# Epoch 075 | Loss 4.68 | Val AUC 0.9861
# Epoch 076 | Loss 4.67 | Val AUC 0.9864
# Epoch 077 | Loss 4.61 | Val AUC 0.9859
# Epoch 078 | Loss 4.66 | Val AUC 0.9859
# Epoch 079 | Loss 4.66 | Val AUC 0.9859
# Epoch 080 | Loss 4.56 | Val AUC 0.9864
# WD=7.742637e-06 | AUC=0.9864 | TopK=0.7595
#
# === Training with weight_decay=2.154435e-05 ===
# Epoch 001 | Loss 17.02 | Val AUC 0.9751
# Epoch 002 | Loss 9.20 | Val AUC 0.9804
# Epoch 003 | Loss 8.38 | Val AUC 0.9822
# Epoch 004 | Loss 7.82 | Val AUC 0.9829
# Epoch 005 | Loss 7.59 | Val AUC 0.9829
# Epoch 006 | Loss 7.19 | Val AUC 0.9830
# Epoch 007 | Loss 6.92 | Val AUC 0.9828
# Epoch 008 | Loss 6.72 | Val AUC 0.9827
# Epoch 009 | Loss 6.48 | Val AUC 0.9829
# Epoch 010 | Loss 6.42 | Val AUC 0.9831
# Epoch 011 | Loss 6.29 | Val AUC 0.9833
# Epoch 012 | Loss 6.13 | Val AUC 0.9836
# Epoch 013 | Loss 6.10 | Val AUC 0.9840
# Epoch 014 | Loss 6.01 | Val AUC 0.9841
# Epoch 015 | Loss 5.97 | Val AUC 0.9842
# Epoch 016 | Loss 6.00 | Val AUC 0.9840
# Epoch 017 | Loss 5.89 | Val AUC 0.9841
# Epoch 018 | Loss 5.82 | Val AUC 0.9844
# Epoch 019 | Loss 5.67 | Val AUC 0.9845
# Epoch 020 | Loss 5.70 | Val AUC 0.9844
# Epoch 021 | Loss 5.66 | Val AUC 0.9843
# Epoch 022 | Loss 5.71 | Val AUC 0.9847
# Epoch 023 | Loss 5.62 | Val AUC 0.9847
# Epoch 024 | Loss 5.59 | Val AUC 0.9851
# Epoch 025 | Loss 5.67 | Val AUC 0.9848
# Epoch 026 | Loss 5.50 | Val AUC 0.9845
# Epoch 027 | Loss 5.55 | Val AUC 0.9847
# Epoch 028 | Loss 5.61 | Val AUC 0.9849
# Epoch 029 | Loss 5.40 | Val AUC 0.9851
# Epoch 030 | Loss 5.37 | Val AUC 0.9848
# Epoch 031 | Loss 5.47 | Val AUC 0.9847
# Epoch 032 | Loss 5.53 | Val AUC 0.9851
# Epoch 033 | Loss 5.44 | Val AUC 0.9853
# Epoch 034 | Loss 5.27 | Val AUC 0.9852
# Epoch 035 | Loss 5.37 | Val AUC 0.9855
# Epoch 036 | Loss 5.32 | Val AUC 0.9854
# Epoch 037 | Loss 5.31 | Val AUC 0.9854
# Epoch 038 | Loss 5.22 | Val AUC 0.9854
# Epoch 039 | Loss 5.41 | Val AUC 0.9852
# Epoch 040 | Loss 5.29 | Val AUC 0.9853
# Epoch 041 | Loss 5.38 | Val AUC 0.9855
# Epoch 042 | Loss 5.29 | Val AUC 0.9854
# Epoch 043 | Loss 5.21 | Val AUC 0.9853
# Epoch 044 | Loss 5.10 | Val AUC 0.9852
# Epoch 045 | Loss 5.19 | Val AUC 0.9858
# Epoch 046 | Loss 5.12 | Val AUC 0.9854
# Epoch 047 | Loss 5.14 | Val AUC 0.9855
# Epoch 048 | Loss 5.11 | Val AUC 0.9859
# Epoch 049 | Loss 5.06 | Val AUC 0.9856
# Epoch 050 | Loss 5.08 | Val AUC 0.9855
# Epoch 051 | Loss 5.15 | Val AUC 0.9857
# Epoch 052 | Loss 4.98 | Val AUC 0.9859
# Epoch 053 | Loss 5.03 | Val AUC 0.9861
# Epoch 054 | Loss 5.12 | Val AUC 0.9856
# Epoch 055 | Loss 5.00 | Val AUC 0.9857
# Epoch 056 | Loss 4.88 | Val AUC 0.9861
# Epoch 057 | Loss 5.08 | Val AUC 0.9856
# Epoch 058 | Loss 4.94 | Val AUC 0.9854
# Epoch 059 | Loss 4.95 | Val AUC 0.9855
# Epoch 060 | Loss 4.78 | Val AUC 0.9854
# Epoch 061 | Loss 4.82 | Val AUC 0.9859
# Epoch 062 | Loss 4.88 | Val AUC 0.9857
# Epoch 063 | Loss 4.91 | Val AUC 0.9859
# Epoch 064 | Loss 4.94 | Val AUC 0.9860
# Epoch 065 | Loss 4.94 | Val AUC 0.9856
# Epoch 066 | Loss 4.89 | Val AUC 0.9861
# Epoch 067 | Loss 4.88 | Val AUC 0.9862
# Epoch 068 | Loss 4.80 | Val AUC 0.9865
# Epoch 069 | Loss 4.89 | Val AUC 0.9865
# Epoch 070 | Loss 4.70 | Val AUC 0.9862
# Epoch 071 | Loss 4.79 | Val AUC 0.9864
# Epoch 072 | Loss 4.75 | Val AUC 0.9865
# Epoch 073 | Loss 4.75 | Val AUC 0.9864
# Epoch 074 | Loss 4.82 | Val AUC 0.9861
# Epoch 075 | Loss 4.81 | Val AUC 0.9865
# Epoch 076 | Loss 4.76 | Val AUC 0.9862
# Epoch 077 | Loss 4.74 | Val AUC 0.9859
# Epoch 078 | Loss 4.69 | Val AUC 0.9856
# Epoch 079 | Loss 4.62 | Val AUC 0.9858
# Epoch 080 | Loss 4.68 | Val AUC 0.9858
# WD=2.154435e-05 | AUC=0.9858 | TopK=0.7785
#
# === Training with weight_decay=5.994843e-05 ===
# Epoch 001 | Loss 17.26 | Val AUC 0.9692
# Epoch 002 | Loss 10.37 | Val AUC 0.9760
# Epoch 003 | Loss 8.90 | Val AUC 0.9795
# Epoch 004 | Loss 8.55 | Val AUC 0.9818
# Epoch 005 | Loss 8.25 | Val AUC 0.9835
# Epoch 006 | Loss 7.62 | Val AUC 0.9846
# Epoch 007 | Loss 7.62 | Val AUC 0.9850
# Epoch 008 | Loss 7.23 | Val AUC 0.9859
# Epoch 009 | Loss 7.19 | Val AUC 0.9861
# Epoch 010 | Loss 7.04 | Val AUC 0.9863
# Epoch 011 | Loss 6.83 | Val AUC 0.9864
# Epoch 012 | Loss 6.60 | Val AUC 0.9870
# Epoch 013 | Loss 6.53 | Val AUC 0.9864
# Epoch 014 | Loss 6.48 | Val AUC 0.9875
# Epoch 015 | Loss 6.34 | Val AUC 0.9875
# Epoch 016 | Loss 6.25 | Val AUC 0.9874
# Epoch 017 | Loss 6.18 | Val AUC 0.9881
# Epoch 018 | Loss 6.01 | Val AUC 0.9881
# Epoch 019 | Loss 6.02 | Val AUC 0.9875
# Epoch 020 | Loss 5.92 | Val AUC 0.9879
# Epoch 021 | Loss 5.93 | Val AUC 0.9877
# Epoch 022 | Loss 5.87 | Val AUC 0.9877
# Epoch 023 | Loss 5.86 | Val AUC 0.9876
# Epoch 024 | Loss 5.74 | Val AUC 0.9875
# Epoch 025 | Loss 5.76 | Val AUC 0.9877
# Epoch 026 | Loss 5.63 | Val AUC 0.9873
# Epoch 027 | Loss 5.55 | Val AUC 0.9874
# Epoch 028 | Loss 5.57 | Val AUC 0.9874
# Epoch 029 | Loss 5.46 | Val AUC 0.9873
# Epoch 030 | Loss 5.55 | Val AUC 0.9875
# Epoch 031 | Loss 5.50 | Val AUC 0.9874
# Epoch 032 | Loss 5.44 | Val AUC 0.9873
# Epoch 033 | Loss 5.36 | Val AUC 0.9874
# Epoch 034 | Loss 5.44 | Val AUC 0.9871
# Epoch 035 | Loss 5.35 | Val AUC 0.9867
# Epoch 036 | Loss 5.21 | Val AUC 0.9868
# Epoch 037 | Loss 5.41 | Val AUC 0.9872
# Epoch 038 | Loss 5.27 | Val AUC 0.9870
# Epoch 039 | Loss 5.21 | Val AUC 0.9868
# Epoch 040 | Loss 5.23 | Val AUC 0.9868
# Epoch 041 | Loss 5.15 | Val AUC 0.9867
# Epoch 042 | Loss 5.27 | Val AUC 0.9867
# Epoch 043 | Loss 5.23 | Val AUC 0.9869
# Epoch 044 | Loss 5.08 | Val AUC 0.9874
# Epoch 045 | Loss 5.26 | Val AUC 0.9870
# Epoch 046 | Loss 5.18 | Val AUC 0.9869
# Epoch 047 | Loss 5.12 | Val AUC 0.9867
# Epoch 048 | Loss 4.96 | Val AUC 0.9867
# Epoch 049 | Loss 5.05 | Val AUC 0.9872
# Epoch 050 | Loss 5.03 | Val AUC 0.9866
# Epoch 051 | Loss 4.90 | Val AUC 0.9864
# Epoch 052 | Loss 4.96 | Val AUC 0.9867
# Epoch 053 | Loss 5.03 | Val AUC 0.9870
# Epoch 054 | Loss 5.00 | Val AUC 0.9867
# Epoch 055 | Loss 4.78 | Val AUC 0.9869
# Epoch 056 | Loss 4.87 | Val AUC 0.9862
# Epoch 057 | Loss 4.86 | Val AUC 0.9861
# Epoch 058 | Loss 4.87 | Val AUC 0.9864
# Epoch 059 | Loss 4.90 | Val AUC 0.9866
# Epoch 060 | Loss 4.86 | Val AUC 0.9863
# Epoch 061 | Loss 4.86 | Val AUC 0.9858
# Epoch 062 | Loss 4.74 | Val AUC 0.9856
# Epoch 063 | Loss 4.71 | Val AUC 0.9866
# Epoch 064 | Loss 4.89 | Val AUC 0.9862
# Epoch 065 | Loss 4.73 | Val AUC 0.9860
# Epoch 066 | Loss 4.73 | Val AUC 0.9863
# Epoch 067 | Loss 4.71 | Val AUC 0.9860
# ...
# Epoch 005 | Loss 8.14 | Val AUC 0.9789
# Epoch 006 | Loss 8.10 | Val AUC 0.9795
# Epoch 007 | Loss 7.81 | Val AUC 0.9801
# Epoch 008 | Loss 7.34 | Val AUC 0.9806
# Epoch 009 | Loss 7.49 | Val AUC 0.9814
# Epoch 010 | Loss 7.11 | Val AUC 0.9821
# Epoch 011 | Loss 7.06 | Val AUC 0.9829
# Epoch 012 | Loss 6.88 | Val AUC 0.9828
# Epoch 013 | Loss 6.76 | Val AUC 0.9830
# Epoch 014 | Loss 6.61 | Val AUC 0.9839
# Epoch 015 | Loss 6.38 | Val AUC 0.9843
# Epoch 016 | Loss 6.27 | Val AUC 0.9852
# Epoch 017 | Loss 6.17 | Val AUC 0.9856
# Epoch 018 | Loss 6.25 | Val AUC 0.9855
# Epoch 019 | Loss 6.28 | Val AUC 0.9856
# Epoch 020 | Loss 6.18 | Val AUC 0.9857
# Epoch 021 | Loss 6.02 | Val AUC 0.9857
# Epoch 022 | Loss 6.04 | Val AUC 0.9861
# Epoch 023 | Loss 6.03 | Val AUC 0.9859
# Epoch 024 | Loss 5.89 | Val AUC 0.9859
# Epoch 025 | Loss 5.78 | Val AUC 0.9861
# Epoch 026 | Loss 5.79 | Val AUC 0.9864
# Epoch 027 | Loss 5.61 | Val AUC 0.9864
# Epoch 028 | Loss 5.62 | Val AUC 0.9863
# Epoch 029 | Loss 5.74 | Val AUC 0.9866
# Epoch 030 | Loss 5.61 | Val AUC 0.9868
# Epoch 031 | Loss 5.53 | Val AUC 0.9866
# Epoch 032 | Loss 5.63 | Val AUC 0.9863
# Epoch 033 | Loss 5.63 | Val AUC 0.9863
# Epoch 034 | Loss 5.48 | Val AUC 0.9866
# Epoch 035 | Loss 5.47 | Val AUC 0.9867
# Epoch 036 | Loss 5.40 | Val AUC 0.9867
# Epoch 037 | Loss 5.31 | Val AUC 0.9867
# Epoch 038 | Loss 5.41 | Val AUC 0.9867
# Epoch 039 | Loss 5.29 | Val AUC 0.9865
# Epoch 040 | Loss 5.47 | Val AUC 0.9866
# Epoch 041 | Loss 5.35 | Val AUC 0.9868
# Epoch 042 | Loss 5.20 | Val AUC 0.9867
# Epoch 043 | Loss 5.24 | Val AUC 0.9865
# Epoch 044 | Loss 5.26 | Val AUC 0.9866
# Epoch 045 | Loss 5.15 | Val AUC 0.9865
# Epoch 046 | Loss 5.30 | Val AUC 0.9864
# Epoch 047 | Loss 5.14 | Val AUC 0.9861
# Epoch 048 | Loss 5.06 | Val AUC 0.9860
# Epoch 049 | Loss 5.04 | Val AUC 0.9861
# Epoch 050 | Loss 5.13 | Val AUC 0.9859
# Epoch 051 | Loss 5.13 | Val AUC 0.9858
# Epoch 052 | Loss 5.06 | Val AUC 0.9856
# Epoch 053 | Loss 5.01 | Val AUC 0.9856
# Epoch 054 | Loss 4.88 | Val AUC 0.9854
# Epoch 055 | Loss 4.95 | Val AUC 0.9855
# Epoch 056 | Loss 4.99 | Val AUC 0.9857
# Epoch 057 | Loss 4.97 | Val AUC 0.9853
# Epoch 058 | Loss 5.01 | Val AUC 0.9854
# Epoch 059 | Loss 4.99 | Val AUC 0.9850
# Epoch 060 | Loss 5.00 | Val AUC 0.9849
# Epoch 061 | Loss 4.89 | Val AUC 0.9848
# Epoch 062 | Loss 4.99 | Val AUC 0.9848
# Epoch 063 | Loss 4.82 | Val AUC 0.9850
# Epoch 064 | Loss 4.84 | Val AUC 0.9853
# Epoch 065 | Loss 4.79 | Val AUC 0.9853
# Epoch 066 | Loss 4.72 | Val AUC 0.9854
# Epoch 067 | Loss 4.90 | Val AUC 0.9853
# Epoch 068 | Loss 4.71 | Val AUC 0.9850
# Epoch 069 | Loss 4.91 | Val AUC 0.9855
# Epoch 070 | Loss 4.74 | Val AUC 0.9850
# Epoch 071 | Loss 4.84 | Val AUC 0.9851
# Epoch 072 | Loss 4.78 | Val AUC 0.9851
# Epoch 073 | Loss 4.73 | Val AUC 0.9853
# Epoch 074 | Loss 4.68 | Val AUC 0.9853
# Epoch 075 | Loss 4.77 | Val AUC 0.9852
# Epoch 076 | Loss 4.66 | Val AUC 0.9854
# Epoch 077 | Loss 4.69 | Val AUC 0.9852
# Epoch 078 | Loss 4.61 | Val AUC 0.9849
# Epoch 079 | Loss 4.65 | Val AUC 0.9848
# Epoch 080 | Loss 4.65 | Val AUC 0.9849
# WD=1.668101e-04 | AUC=0.9849 | TopK=0.7532
#
# === Training with weight_decay=4.641589e-04 ===
# Epoch 001 | Loss 24.37 | Val AUC 0.9662
# Epoch 002 | Loss 11.60 | Val AUC 0.9688
# Epoch 003 | Loss 9.92 | Val AUC 0.9696
# Epoch 004 | Loss 8.91 | Val AUC 0.9728
# Epoch 005 | Loss 8.79 | Val AUC 0.9749
# Epoch 006 | Loss 8.28 | Val AUC 0.9774
# Epoch 007 | Loss 8.07 | Val AUC 0.9781
# Epoch 008 | Loss 7.65 | Val AUC 0.9788
# Epoch 009 | Loss 7.51 | Val AUC 0.9792
# Epoch 010 | Loss 7.37 | Val AUC 0.9797
# Epoch 011 | Loss 7.09 | Val AUC 0.9799
# Epoch 012 | Loss 7.13 | Val AUC 0.9798
# Epoch 013 | Loss 7.03 | Val AUC 0.9800
# Epoch 014 | Loss 6.66 | Val AUC 0.9802
# Epoch 015 | Loss 6.73 | Val AUC 0.9802
# Epoch 016 | Loss 6.65 | Val AUC 0.9806
# Epoch 017 | Loss 6.64 | Val AUC 0.9808
# Epoch 018 | Loss 6.48 | Val AUC 0.9806
# Epoch 019 | Loss 6.40 | Val AUC 0.9810
# Epoch 020 | Loss 6.37 | Val AUC 0.9809
# Epoch 021 | Loss 6.28 | Val AUC 0.9812
# Epoch 022 | Loss 6.10 | Val AUC 0.9814
# Epoch 023 | Loss 6.03 | Val AUC 0.9817
# Epoch 024 | Loss 6.02 | Val AUC 0.9817
# Epoch 025 | Loss 6.05 | Val AUC 0.9816
# Epoch 026 | Loss 5.95 | Val AUC 0.9819
# Epoch 027 | Loss 5.93 | Val AUC 0.9819
# Epoch 028 | Loss 5.81 | Val AUC 0.9819
# Epoch 029 | Loss 5.74 | Val AUC 0.9820
# Epoch 030 | Loss 6.05 | Val AUC 0.9828
# Epoch 031 | Loss 5.83 | Val AUC 0.9825
# Epoch 032 | Loss 5.63 | Val AUC 0.9826
# Epoch 033 | Loss 5.63 | Val AUC 0.9827
# Epoch 034 | Loss 5.60 | Val AUC 0.9829
# Epoch 035 | Loss 5.63 | Val AUC 0.9830
# Epoch 036 | Loss 5.65 | Val AUC 0.9828
# Epoch 037 | Loss 5.57 | Val AUC 0.9828
# Epoch 038 | Loss 5.51 | Val AUC 0.9830
# Epoch 039 | Loss 5.54 | Val AUC 0.9829
# Epoch 040 | Loss 5.48 | Val AUC 0.9831
# Epoch 041 | Loss 5.39 | Val AUC 0.9831
# Epoch 042 | Loss 5.51 | Val AUC 0.9832
# Epoch 043 | Loss 5.40 | Val AUC 0.9830
# Epoch 044 | Loss 5.33 | Val AUC 0.9832
# Epoch 045 | Loss 5.29 | Val AUC 0.9832
# Epoch 046 | Loss 5.31 | Val AUC 0.9830
# Epoch 047 | Loss 5.28 | Val AUC 0.9834
# Epoch 048 | Loss 5.21 | Val AUC 0.9833
# Epoch 049 | Loss 5.18 | Val AUC 0.9835
# Epoch 050 | Loss 5.18 | Val AUC 0.9838
# Epoch 051 | Loss 5.22 | Val AUC 0.9837
# Epoch 052 | Loss 5.22 | Val AUC 0.9831
# Epoch 053 | Loss 5.07 | Val AUC 0.9837
# Epoch 054 | Loss 5.14 | Val AUC 0.9841
# Epoch 055 | Loss 5.12 | Val AUC 0.9839
# Epoch 056 | Loss 5.14 | Val AUC 0.9836
# Epoch 057 | Loss 5.14 | Val AUC 0.9838
# Epoch 058 | Loss 5.00 | Val AUC 0.9839
# Epoch 059 | Loss 5.02 | Val AUC 0.9836
# Epoch 060 | Loss 5.14 | Val AUC 0.9837
# Epoch 061 | Loss 5.14 | Val AUC 0.9839
# Epoch 062 | Loss 5.03 | Val AUC 0.9835
# Epoch 063 | Loss 5.05 | Val AUC 0.9839
# Epoch 064 | Loss 4.98 | Val AUC 0.9838
# Epoch 065 | Loss 4.92 | Val AUC 0.9839
# Epoch 066 | Loss 4.96 | Val AUC 0.9841
# Epoch 067 | Loss 5.03 | Val AUC 0.9841
# Epoch 068 | Loss 4.86 | Val AUC 0.9839
# Epoch 069 | Loss 4.88 | Val AUC 0.9839
# Epoch 070 | Loss 4.94 | Val AUC 0.9842
# Epoch 071 | Loss 4.72 | Val AUC 0.9840
# Epoch 072 | Loss 4.85 | Val AUC 0.9841
# Epoch 073 | Loss 4.73 | Val AUC 0.9841
# Epoch 074 | Loss 4.91 | Val AUC 0.9841
# Epoch 075 | Loss 4.77 | Val AUC 0.9842
# Epoch 076 | Loss 4.75 | Val AUC 0.9842
# Epoch 077 | Loss 4.82 | Val AUC 0.9845
# Epoch 078 | Loss 4.70 | Val AUC 0.9841
# Epoch 079 | Loss 4.70 | Val AUC 0.9842
# Epoch 080 | Loss 4.59 | Val AUC 0.9840
# WD=4.641589e-04 | AUC=0.9840 | TopK=0.7595
#
# === Training with weight_decay=1.291550e-03 ===
# Epoch 001 | Loss 23.58 | Val AUC 0.9264
# Epoch 002 | Loss 11.70 | Val AUC 0.9488
# Epoch 003 | Loss 9.99 | Val AUC 0.9592
# Epoch 004 | Loss 8.99 | Val AUC 0.9667
# Epoch 005 | Loss 8.70 | Val AUC 0.9700
# Epoch 006 | Loss 8.32 | Val AUC 0.9739
# Epoch 007 | Loss 8.07 | Val AUC 0.9762
# Epoch 008 | Loss 7.99 | Val AUC 0.9766
# Epoch 009 | Loss 7.54 | Val AUC 0.9783
# Epoch 010 | Loss 7.36 | Val AUC 0.9784
# Epoch 011 | Loss 7.32 | Val AUC 0.9797
# Epoch 012 | Loss 7.23 | Val AUC 0.9800
# Epoch 013 | Loss 7.08 | Val AUC 0.9808
# Epoch 014 | Loss 6.96 | Val AUC 0.9814
# Epoch 015 | Loss 6.68 | Val AUC 0.9820
# Epoch 016 | Loss 6.58 | Val AUC 0.9830
# Epoch 017 | Loss 6.50 | Val AUC 0.9828
# Epoch 018 | Loss 6.42 | Val AUC 0.9832
# Epoch 019 | Loss 6.34 | Val AUC 0.9836
# Epoch 020 | Loss 6.37 | Val AUC 0.9836
# Epoch 021 | Loss 6.32 | Val AUC 0.9839
# Epoch 022 | Loss 6.14 | Val AUC 0.9839
# Epoch 023 | Loss 6.17 | Val AUC 0.9836
# Epoch 024 | Loss 6.03 | Val AUC 0.9838
# Epoch 025 | Loss 6.00 | Val AUC 0.9838
# Epoch 026 | Loss 5.96 | Val AUC 0.9842
# Epoch 027 | Loss 5.95 | Val AUC 0.9843
# Epoch 028 | Loss 5.81 | Val AUC 0.9843
# Epoch 029 | Loss 5.89 | Val AUC 0.9844
# Epoch 030 | Loss 5.79 | Val AUC 0.9845
# Epoch 031 | Loss 5.73 | Val AUC 0.9844
# Epoch 032 | Loss 5.89 | Val AUC 0.9846
# Epoch 033 | Loss 5.67 | Val AUC 0.9845
# Epoch 034 | Loss 5.66 | Val AUC 0.9845
# Epoch 035 | Loss 5.66 | Val AUC 0.9847
# Epoch 036 | Loss 5.62 | Val AUC 0.9845
# Epoch 037 | Loss 5.54 | Val AUC 0.9847
# Epoch 038 | Loss 5.61 | Val AUC 0.9848
# Epoch 039 | Loss 5.65 | Val AUC 0.9849
# Epoch 040 | Loss 5.60 | Val AUC 0.9849
# Epoch 041 | Loss 5.51 | Val AUC 0.9851
# Epoch 042 | Loss 5.50 | Val AUC 0.9849
# Epoch 043 | Loss 5.61 | Val AUC 0.9851
# Epoch 044 | Loss 5.35 | Val AUC 0.9850
# Epoch 045 | Loss 5.45 | Val AUC 0.9850
# Epoch 046 | Loss 5.37 | Val AUC 0.9851
# Epoch 047 | Loss 5.37 | Val AUC 0.9853
# Epoch 048 | Loss 5.32 | Val AUC 0.9852
# Epoch 049 | Loss 5.26 | Val AUC 0.9852
# Epoch 050 | Loss 5.27 | Val AUC 0.9852
# Epoch 051 | Loss 5.22 | Val AUC 0.9851
# Epoch 052 | Loss 5.20 | Val AUC 0.9854
# Epoch 053 | Loss 5.24 | Val AUC 0.9854
# Epoch 054 | Loss 5.26 | Val AUC 0.9854
# Epoch 055 | Loss 5.21 | Val AUC 0.9854
# Epoch 056 | Loss 5.14 | Val AUC 0.9853
# Epoch 057 | Loss 5.20 | Val AUC 0.9854
# Epoch 058 | Loss 5.10 | Val AUC 0.9854
# Epoch 059 | Loss 5.11 | Val AUC 0.9857
# Epoch 060 | Loss 5.06 | Val AUC 0.9861
# Epoch 061 | Loss 5.06 | Val AUC 0.9860
# Epoch 062 | Loss 5.03 | Val AUC 0.9870
# Epoch 063 | Loss 5.02 | Val AUC 0.9870
# Epoch 064 | Loss 4.98 | Val AUC 0.9872
# Epoch 065 | Loss 5.04 | Val AUC 0.9872
# Epoch 066 | Loss 4.91 | Val AUC 0.9873
# Epoch 067 | Loss 4.93 | Val AUC 0.9873
# Epoch 068 | Loss 4.98 | Val AUC 0.9875
# Epoch 069 | Loss 5.00 | Val AUC 0.9878
# Epoch 070 | Loss 4.87 | Val AUC 0.9878
# Epoch 071 | Loss 4.99 | Val AUC 0.9875
# Epoch 072 | Loss 4.82 | Val AUC 0.9877
# Epoch 073 | Loss 4.74 | Val AUC 0.9881
# Epoch 074 | Loss 4.78 | Val AUC 0.9883
# Epoch 075 | Loss 4.91 | Val AUC 0.9876
# Epoch 076 | Loss 4.73 | Val AUC 0.9881
# Epoch 077 | Loss 4.86 | Val AUC 0.9875
# Epoch 078 | Loss 4.92 | Val AUC 0.9878
# Epoch 079 | Loss 4.80 | Val AUC 0.9885
# Epoch 080 | Loss 4.74 | Val AUC 0.9882
# WD=1.291550e-03 | AUC=0.9882 | TopK=0.7658
#
# === Training with weight_decay=3.593814e-03 ===
# Epoch 001 | Loss 18.74 | Val AUC 0.9595
# Epoch 002 | Loss 10.10 | Val AUC 0.9717
# Epoch 003 | Loss 8.90 | Val AUC 0.9753
# Epoch 004 | Loss 8.55 | Val AUC 0.9768
# Epoch 005 | Loss 7.98 | Val AUC 0.9777
# Epoch 006 | Loss 7.73 | Val AUC 0.9782
# Epoch 007 | Loss 7.49 | Val AUC 0.9788
# Epoch 008 | Loss 7.24 | Val AUC 0.9791
# Epoch 009 | Loss 6.89 | Val AUC 0.9793
# Epoch 010 | Loss 6.91 | Val AUC 0.9792
# Epoch 011 | Loss 6.69 | Val AUC 0.9793
# Epoch 012 | Loss 6.62 | Val AUC 0.9796
# Epoch 013 | Loss 6.56 | Val AUC 0.9799
# Epoch 014 | Loss 6.42 | Val AUC 0.9803
# Epoch 015 | Loss 6.30 | Val AUC 0.9806
# Epoch 016 | Loss 6.22 | Val AUC 0.9809
# Epoch 017 | Loss 6.15 | Val AUC 0.9806
# Epoch 018 | Loss 6.15 | Val AUC 0.9817
# Epoch 019 | Loss 6.10 | Val AUC 0.9816
# Epoch 020 | Loss 6.02 | Val AUC 0.9816
# Epoch 021 | Loss 5.99 | Val AUC 0.9817
# Epoch 022 | Loss 5.87 | Val AUC 0.9820
# Epoch 023 | Loss 5.86 | Val AUC 0.9822
# Epoch 024 | Loss 5.70 | Val AUC 0.9822
# Epoch 025 | Loss 5.80 | Val AUC 0.9824
# Epoch 026 | Loss 5.62 | Val AUC 0.9826
# Epoch 027 | Loss 5.71 | Val AUC 0.9824
# Epoch 028 | Loss 5.56 | Val AUC 0.9827
# Epoch 029 | Loss 5.58 | Val AUC 0.9825
# Epoch 030 | Loss 5.61 | Val AUC 0.9827
# Epoch 031 | Loss 5.61 | Val AUC 0.9827
# Epoch 032 | Loss 5.42 | Val AUC 0.9828
# Epoch 033 | Loss 5.42 | Val AUC 0.9830
# Epoch 034 | Loss 5.34 | Val AUC 0.9830
# Epoch 035 | Loss 5.42 | Val AUC 0.9830
# Epoch 036 | Loss 5.39 | Val AUC 0.9834
# Epoch 037 | Loss 5.36 | Val AUC 0.9831
# Epoch 038 | Loss 5.32 | Val AUC 0.9833
# Epoch 039 | Loss 5.36 | Val AUC 0.9833
# Epoch 040 | Loss 5.27 | Val AUC 0.9832
# Epoch 041 | Loss 5.24 | Val AUC 0.9836
# Epoch 042 | Loss 5.17 | Val AUC 0.9837
# Epoch 043 | Loss 5.16 | Val AUC 0.9840
# Epoch 044 | Loss 5.32 | Val AUC 0.9838
# Epoch 045 | Loss 5.14 | Val AUC 0.9836
# Epoch 046 | Loss 5.15 | Val AUC 0.9831
# Epoch 047 | Loss 5.12 | Val AUC 0.9832
# Epoch 048 | Loss 5.13 | Val AUC 0.9833
# Epoch 049 | Loss 5.10 | Val AUC 0.9831
# Epoch 050 | Loss 5.20 | Val AUC 0.9835
# Epoch 051 | Loss 5.05 | Val AUC 0.9832
# Epoch 052 | Loss 5.05 | Val AUC 0.9834
# Epoch 053 | Loss 5.03 | Val AUC 0.9834
# Epoch 054 | Loss 4.92 | Val AUC 0.9835
# Epoch 055 | Loss 5.06 | Val AUC 0.9835
# Epoch 056 | Loss 5.05 | Val AUC 0.9836
# Epoch 057 | Loss 5.01 | Val AUC 0.9835
# Epoch 058 | Loss 4.90 | Val AUC 0.9838
# Epoch 059 | Loss 4.93 | Val AUC 0.9836
# Epoch 060 | Loss 5.01 | Val AUC 0.9835
# Epoch 061 | Loss 5.07 | Val AUC 0.9834
# Epoch 062 | Loss 4.94 | Val AUC 0.9835
# Epoch 063 | Loss 4.92 | Val AUC 0.9837
# Epoch 064 | Loss 4.91 | Val AUC 0.9838
# Epoch 065 | Loss 4.85 | Val AUC 0.9838
# Epoch 066 | Loss 4.80 | Val AUC 0.9838
# Epoch 067 | Loss 4.91 | Val AUC 0.9840
# Epoch 068 | Loss 4.82 | Val AUC 0.9839
# Epoch 069 | Loss 4.84 | Val AUC 0.9840
# Epoch 070 | Loss 4.78 | Val AUC 0.9839
# Epoch 071 | Loss 4.78 | Val AUC 0.9844
# Epoch 072 | Loss 4.76 | Val AUC 0.9842
# Epoch 073 | Loss 4.70 | Val AUC 0.9844
# Epoch 074 | Loss 4.63 | Val AUC 0.9841
# Epoch 075 | Loss 4.68 | Val AUC 0.9844
# Epoch 076 | Loss 4.81 | Val AUC 0.9846
# Epoch 077 | Loss 4.63 | Val AUC 0.9845
# Epoch 078 | Loss 4.70 | Val AUC 0.9843
# Epoch 079 | Loss 4.76 | Val AUC 0.9842
# Epoch 080 | Loss 4.70 | Val AUC 0.9843
# WD=3.593814e-03 | AUC=0.9843 | TopK=0.7595
#
# === Training with weight_decay=1.000000e-02 ===
# Epoch 001 | Loss 13.84 | Val AUC 0.9747
# Epoch 002 | Loss 8.85 | Val AUC 0.9794
# Epoch 003 | Loss 8.40 | Val AUC 0.9810
# Epoch 004 | Loss 7.86 | Val AUC 0.9824
# Epoch 005 | Loss 7.42 | Val AUC 0.9828
# Epoch 006 | Loss 7.30 | Val AUC 0.9832
# Epoch 007 | Loss 7.03 | Val AUC 0.9835
# Epoch 008 | Loss 6.86 | Val AUC 0.9836
# Epoch 009 | Loss 6.70 | Val AUC 0.9841
# Epoch 010 | Loss 6.61 | Val AUC 0.9840
# Epoch 011 | Loss 6.45 | Val AUC 0.9844
# Epoch 012 | Loss 6.37 | Val AUC 0.9846
# Epoch 013 | Loss 6.22 | Val AUC 0.9846
# Epoch 014 | Loss 6.25 | Val AUC 0.9849
# Epoch 015 | Loss 6.13 | Val AUC 0.9850
# Epoch 016 | Loss 6.08 | Val AUC 0.9851
# Epoch 017 | Loss 6.19 | Val AUC 0.9854
# Epoch 018 | Loss 5.95 | Val AUC 0.9856
# Epoch 019 | Loss 5.81 | Val AUC 0.9858
# Epoch 020 | Loss 5.77 | Val AUC 0.9861
# Epoch 021 | Loss 5.83 | Val AUC 0.9859
# Epoch 022 | Loss 5.69 | Val AUC 0.9859
# Epoch 023 | Loss 5.76 | Val AUC 0.9860
# Epoch 024 | Loss 5.68 | Val AUC 0.9864
# Epoch 025 | Loss 5.50 | Val AUC 0.9866
# Epoch 026 | Loss 5.57 | Val AUC 0.9869
# Epoch 027 | Loss 5.55 | Val AUC 0.9866
# Epoch 028 | Loss 5.48 | Val AUC 0.9868
# Epoch 029 | Loss 5.44 | Val AUC 0.9865
# Epoch 030 | Loss 5.39 | Val AUC 0.9864
# Epoch 031 | Loss 5.36 | Val AUC 0.9866
# Epoch 032 | Loss 5.44 | Val AUC 0.9871
# Epoch 033 | Loss 5.36 | Val AUC 0.9874
# Epoch 034 | Loss 5.29 | Val AUC 0.9874
# Epoch 035 | Loss 5.35 | Val AUC 0.9877
# Epoch 036 | Loss 5.39 | Val AUC 0.9876
# Epoch 037 | Loss 5.31 | Val AUC 0.9876
# Epoch 038 | Loss 5.36 | Val AUC 0.9876
# Epoch 039 | Loss 5.35 | Val AUC 0.9870
# Epoch 040 | Loss 5.23 | Val AUC 0.9874
# Epoch 041 | Loss 5.21 | Val AUC 0.9874
# Epoch 042 | Loss 5.12 | Val AUC 0.9874
# Epoch 043 | Loss 5.33 | Val AUC 0.9873
# Epoch 044 | Loss 5.05 | Val AUC 0.9873
# Epoch 045 | Loss 5.06 | Val AUC 0.9871
# Epoch 046 | Loss 5.13 | Val AUC 0.9873
# Epoch 047 | Loss 5.21 | Val AUC 0.9876
# Epoch 048 | Loss 5.14 | Val AUC 0.9869
# Epoch 049 | Loss 5.03 | Val AUC 0.9868
# Epoch 050 | Loss 5.09 | Val AUC 0.9867
# Epoch 051 | Loss 5.07 | Val AUC 0.9871
# Epoch 052 | Loss 5.07 | Val AUC 0.9867
# Epoch 053 | Loss 5.02 | Val AUC 0.9865
# Epoch 054 | Loss 5.02 | Val AUC 0.9862
# Epoch 055 | Loss 4.89 | Val AUC 0.9861
# Epoch 056 | Loss 5.05 | Val AUC 0.9860
# Epoch 057 | Loss 4.94 | Val AUC 0.9862
# Epoch 058 | Loss 4.87 | Val AUC 0.9862
# Epoch 059 | Loss 4.90 | Val AUC 0.9862
# Epoch 060 | Loss 4.86 | Val AUC 0.9864
# Epoch 061 | Loss 4.83 | Val AUC 0.9865
# Epoch 062 | Loss 4.82 | Val AUC 0.9864
# Epoch 063 | Loss 4.84 | Val AUC 0.9866
# Epoch 064 | Loss 4.82 | Val AUC 0.9868
# Epoch 065 | Loss 4.84 | Val AUC 0.9867
# Epoch 066 | Loss 4.84 | Val AUC 0.9864
# Epoch 067 | Loss 4.78 | Val AUC 0.9862
# Epoch 068 | Loss 4.66 | Val AUC 0.9859
# Epoch 069 | Loss 4.76 | Val AUC 0.9858
# Epoch 070 | Loss 4.67 | Val AUC 0.9860
# Epoch 071 | Loss 4.80 | Val AUC 0.9862
# Epoch 072 | Loss 4.72 | Val AUC 0.9860
# Epoch 073 | Loss 4.80 | Val AUC 0.9863
# Epoch 074 | Loss 4.67 | Val AUC 0.9861
# Epoch 075 | Loss 4.63 | Val AUC 0.9861
# Epoch 076 | Loss 4.67 | Val AUC 0.9866
# Epoch 077 | Loss 4.78 | Val AUC 0.9864
# Epoch 078 | Loss 4.49 | Val AUC 0.9861
# Epoch 079 | Loss 4.60 | Val AUC 0.9856
# Epoch 080 | Loss 4.58 | Val AUC 0.9861
# WD=1.000000e-02 | AUC=0.9861 | TopK=0.7722
#
# Best weight decay: 1e-06
# Best Validation TopK: 0.7785
#
# ENGINEERED RESULT:
# Best WD: 1e-06
# Val AUC: 0.9875
# Val TopK: 0.7785

# %%
for entry in results_nn:

    history = entry["tuning_history"]

    wd_vals   = [h[0] for h in history]
    topk_vals = [h[2] for h in history]

    plt.figure(figsize=(8, 5))
    plt.semilogx(wd_vals, topk_vals, marker='o')

    plt.axvline(
        x=entry["best_wd"],
        linestyle='--',
        alpha=0.5,
        label=f"Best WD ({entry['best_wd']:.2e})"
    )

    plt.title(f"NN Tuning Curve ({entry['data_type']})")
    plt.xlabel("Weight Decay (Log Scale)")
    plt.ylabel("Validation Top-12 Recall")
    plt.grid(True, which="both", alpha=0.3)
    plt.legend()
    plt.show()

# %% [markdown]
# ## Results:

# %% [markdown]
# ### Design Philosophy
#
# The core idea behind this model is that All-Star selection is not an independent classification problem, but a structured selection problem. Players are not evaluated in isolation; they are competing within a fixed, constrained pool defined by season and conference.
#
# Rather than predicting probabilities and thresholding, the model is designed to directly approximate the selection process. This is done by enforcing three properties during training: (1) the correct number of players must be selected (top-k structure), (2) true All-Stars should rank above non-All-Stars (pairwise ordering), and (3) outputs should remain probabilistically meaningful (calibration via BCE).
#
# The architecture reflects this structure. A shared representation is learned for each player, but attention operates at the group level, allowing players to be evaluated relative to others in the same selection pool. Separate heads for starters and reserves introduce role-specific scoring, while still allowing interaction through shared features and attention.
#
# Loss design is intentionally compositional. The selection loss enforces global constraints, the pairwise loss enforces local ordering, and BCE stabilizes optimization. Additional penalties ensure that roster construction remains valid (positional balance and no overlap between starter/reserve selections).
#
# Overall, the model is built to align the training objective with the actual decision process. Instead of hoping a classifier generalizes to structured selection, the structure is explicitly encoded into both the architecture and the loss.

# %% [markdown]
# ### Training / Model Summary
#
# | Metric        | Value  |
# |---------------|--------|
# | Initial Loss  | 18.02  |
# | Final Loss    | 4.63   |
# | Best Val AUC  | 0.9888 |
# | Epochs        | 80     |
# | AUC      | 0.9827 |
# | Accuracy | 0.9740 |
# | Precision| 0.8333 |
# | Recall   | 0.7547 |
# | F1 Score | 0.7921 |
#
# ### Per-Season Performance (Conference Split)
#
# | Season | Conf  | AUC    | Accuracy | Precision | Recall | F1   | Top-12 Recall | Top-12 Accuracy |
# |--------|-------|--------|----------|-----------|--------|------|---------------|------------|
# | 2022   | West  | 0.9771 | 0.976    | 0.833     | 0.769  | 0.800 | 0.769 | 0.833 |
# | 2022   | East  | 0.9939 | 0.990    | 1.000     | 0.857  | 0.923 | 0.857 | 1.000 |
# | 2023   | West  | 0.9856 | 0.959    | 0.750     | 0.643  | 0.692 | 0.643 | 0.750 |
# | 2023   | East  | 0.9808 | 0.956    | 0.667     | 0.615  | 0.640 | 0.615 | 0.667 |
# | 2024   | West  | 0.9899 | 0.968    | 0.750     | 0.750  | 0.750 | 0.750 | 0.750 |
# | 2024   | East  | 0.9914 | 0.981    | 0.917     | 0.786  | 0.846 | 0.786 | 0.917 |
# | 2025   | West  | 0.9873 | 0.975    | 0.833     | 0.769  | 0.800 | 0.769 | 0.833 |
# | 2025   | East  | 0.9938 | 0.986    | 0.917     | 0.846  | 0.880 | 0.846 | 0.917 |
#
# ### Per-Season (Average)
#
# | Season | AUC    | Accuracy | Precision | Recall | F1   | Top-12 Recall | Top-12 Accuracy |
# |--------|--------|----------|-----------|--------|------|---------------|------------|
# | 2022   | 0.9816 | 0.983    | 0.917     | 0.815  | 0.863 | 0.815 | 0.917 |
# | 2023   | 0.9798 | 0.957    | 0.708     | 0.630  | 0.667 | 0.630 | 0.708 |
# | 2024   | 0.9911 | 0.975    | 0.833     | 0.769  | 0.800 | 0.769 | 0.833 |
# | 2025   | 0.9903 | 0.981    | 0.875     | 0.808  | 0.840 | 0.808 | 0.875 |
#
# ### Overall Per-Season Performance
#
# | Metric           | Value  |
# |------------------|--------|
# | AUC              | 0.9857 |
# | Accuracy         | 0.9739 |
# | Precision        | 0.8333 |
# | Recall           | 0.7553 |
# | F1 Score         | 0.7924 |
# | Top-12 Recall    | 0.7553 |
# | Top-12 Accuracy  | 0.8333 |
#
# ### Final Model Performance
#
# | Category        | Metric        | Value  |
# |-----------------|--------------|--------|
# | Global          | AUC          | 0.9827 |
# | Global          | Accuracy     | 0.9740 |
# | Global          | Precision    | 0.8333 |
# | Global          | Recall       | 0.7547 |
# | Global          | F1 Score     | 0.7921 |
# | Per-Season Avg  | AUC          | 0.9857 |
# | Per-Season Avg  | Accuracy     | 0.9739 |
# | Per-Season Avg  | Precision    | 0.8333 |
# | Per-Season Avg  | Recall       | 0.7553 |
# | Per-Season Avg  | F1 Score     | 0.7924 |
# | Selection       | Top-12 Recall | 0.7553 |
# | Selection       | Top-12 Accuracy   | 0.8333 |

# %% [markdown]
# ## Model Comparison: Neural Network vs Logistic Regression
#
# The neural network extends the linear baseline by explicitly modeling the structure of the selection process rather than relying on feature engineering alone. While logistic regression achieves strong performance through carefully constructed, group-centered features, it remains limited to additive relationships and cannot adapt to context-dependent interactions between players.
#
# The neural network addresses this by learning representations over grouped player sets. Embeddings encode categorical structure (conference, position, season), while attention allows each player’s evaluation to depend on the surrounding pool—effectively modeling competition within a selection group. The training objective further aligns with the task by combining soft top-k selection, pairwise ranking, and probabilistic calibration, directly optimizing for roster construction rather than independent classification.
#
# Empirically, this results in improved recall and F1, particularly in edge cases where multiple candidates have similar profiles and selection depends on nuanced trade-offs. Conceptually, the key distinction is that logistic regression treats players independently and relies on engineered proxies for comparison, whereas the neural network learns these comparisons implicitly through interaction-aware representations.
#
# As a result, the neural network is not simply a more complex model, but a better-aligned one: it reflects the grouped, competitive, and constrained nature of All-Star selection.
#
#
# ### Global Performance
#
# | Metric     | Neural Network | Logistic Regression |
# |------------|---------------|---------------------|
# | AUC        | 0.9827        | 0.9872              |
# | Accuracy   | 0.9740        | 0.9678              |
# | Precision  | 0.8333        | 0.7813              |
# | Recall     | 0.7547        | 0.7075              |
# | F1 Score   | 0.7921        | 0.7426              |
#
# ### Per-Season Average Performance
#
# | Metric     | Neural Network | Logistic Regression |
# |------------|---------------|---------------------|
# | AUC        | 0.9857        | 0.9873              |
# | Accuracy   | 0.9739        | 0.9677              |
# | Precision  | 0.8333        | 0.7813              |
# | Recall     | 0.7553        | 0.7083              |
# | F1 Score   | 0.7924        | 0.7429              |
#
# ### Selection Quality
#
# | Metric         | Neural Network | Logistic Regression |
# |----------------|---------------|---------------------|
# | Top-12 Recall   | 0.7553        | 0.7083              |
# | Top-12 Accuracy| 0.8333        | 0.7813              |
#
# ### Per-Season Performance Comparison
#
# | Season | Model                | AUC    | Accuracy | Precision | Recall | F1   |
# |--------|----------------------|--------|----------|-----------|--------|------|
# | 2022   | Neural Network       | 0.9816 | 0.983    | 0.917     | 0.815  | 0.863 |
# | 2022   | Logistic Regression  | 0.9829 | 0.968    | 0.792     | 0.704  | 0.745 |
# | 2023   | Neural Network       | 0.9798 | 0.957    | 0.708     | 0.630  | 0.667 |
# | 2023   | Logistic Regression  | 0.9848 | 0.957    | 0.708     | 0.630  | 0.667 |
# | 2024   | Neural Network       | 0.9911 | 0.975    | 0.833     | 0.769  | 0.800 |
# | 2024   | Logistic Regression  | 0.9905 | 0.970    | 0.792     | 0.731  | 0.760 |
# | 2025   | Neural Network       | 0.9903 | 0.981    | 0.875     | 0.808  | 0.840 |
# | 2025   | Logistic Regression  | 0.9911 | 0.976    | 0.833     | 0.769  | 0.800 |
